# %%
# !pip install langchain chromadb tiktoken
# Out:
# Requirement already satisfied: langchain in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: chromadb in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: tiktoken in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (0.3.60)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: pyproject_hooks in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.14.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.31.2)
# Requirement already satisfied: filelock in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sreekeerthireddythat\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
# Step 2: Imports
import os
import shutil
import requests
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain.embeddings.base import Embeddings

# %%
with open("transportation_test_text.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
# Step 4: Split the text into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)
chunks = text_splitter.split_text(text)
documents = [Document(page_content=chunk) for chunk in chunks]

# %%
chunks
# Out:
# ['The invention of the wheel revolutionized human movement. American whole magazine truth stop whose. On traditional measure example sense peace. Would mouth relate own chair. Role together range line. Government first policy daughter.',
#  'Governments worldwide are investing in infrastructure to support new transport methods. Kind miss artist truth trouble behavior style. Ability management test during foot that course nothing. Sound central myself before year. Your majority feeling fact by four two. White owner onto knowledge other. First drug contain start almost wonder.',
#  'Today, electric vehicles and autonomous cars represent a new era of mobility. Attorney quickly candidate change although bag record. Raise study modern miss dog Democrat quickly. Often late produce you true soldier. Food break onto friend.\n\nHigh-speed trains and subways reshaped urban transportation. Administration even relate head color. Staff beyond chair recently and off. Own available buy country store build before. Already against which continue.',
#  'Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Decision song view age international big employee. Author feeling job article level. Beyond write current grow rule stuff truth college.\n\nToday, electric vehicles and autonomous cars represent a new era of mobility. Small citizen class morning. Others kind company likely. Tonight themselves true power home price. Night actually score from.',
#  'High-speed trains and subways reshaped urban transportation. Exactly drive well good explain grow water. Car financial security stock ball organization recognize civil. Pm her then nothing increase.\n\nThe fusion of AI and transportation is giving rise to smart mobility systems. Industry product another knowledge else citizen month. Traditional page a although for study anyone. Could yourself plan base rise would. Wear individual about add senior woman. Partner couple part cup few read consider.',
#  'During the Industrial Revolution, steam engines transformed both land and sea travel. Physical against trial son break either. Stage population boy child surface amount day. Next water voice travel among. Pretty Republican total policy head Mrs debate onto. Catch even front. Responsibility full per among clearly word.',
#  'Sustainable transportation is becoming increasingly important in the fight against climate change. House nature fall long dream answer. Tax rock few structure. Increase between training listen subject. Buy break marriage also friend reach.\n\nFuturistic ideas such as hyperloops, flying cars, and space travel dominate discussions. Phone heart window police. Space cup determine his. Hour million large major.',
#  'Governments worldwide are investing in infrastructure to support new transport methods. Institution happy write end since. Court boy state table agree moment. Budget huge debate among way. Perhaps bit learn gun still. Writer work chance image. There many true follow marriage material.',
#  'Sustainable transportation is becoming increasingly important in the fight against climate change. Particular despite future while together stand along. Themselves owner choose here. Responsibility southern at be than. At candidate feel.',
#  'Today, electric vehicles and autonomous cars represent a new era of mobility. Technology song than leave he him. Maybe off question source serious wrong section. Face top individual win suddenly. Parent do ten after those scientist. Medical effort assume teacher wall.',
#  'Sustainable transportation is becoming increasingly important in the fight against climate change. His himself clearly very dream role. Area along individual man tell response. Special good along letter. Another likely character allow pay picture black.',
#  'High-speed trains and subways reshaped urban transportation. Crime situation since book art red. Place full buy radio perform small camera treatment. True their race special million. Although hot he couple ground. Away and various main too war project occur. Director simply those physical maybe.',
#  'Governments worldwide are investing in infrastructure to support new transport methods. Medical watch certainly through instead base. Indeed between similar safe. Social issue indicate. Try while reveal bad audience grow ahead. Concern store discover hand others century. Daughter purpose voice.\n\nDuring the Industrial Revolution, steam engines transformed both land and sea travel. Fall ready usually. Teacher cost both general where. Agreement decade friend which.',
#  'During the Industrial Revolution, steam engines transformed both land and sea travel. Player contain year bill ok choose today. Source firm drug senior. Head production technology over hour. Car federal indicate unit.',
#  'In ancient times, transportation was limited to walking and animal domestication. Fear great easy plan PM more. Impact individual rock fly daughter fall. Before control board born painting child reflect. Control instead company where future model. Leg PM low data ability recognize. Left despite boy without feeling participant interest seem.',
#  'In ancient times, transportation was limited to walking and animal domestication. Set discussion seven evidence worker building this. A huge three. Know second government the pull cultural.\n\nFuturistic ideas such as hyperloops, flying cars, and space travel dominate discussions.
',
#  'Governments worldwide are investing in infrastructure to support new transport methods. Kid big without laugh. Process deal without party area concern. Girl quite break they. Run foreign floor open. Memory drug road imagine standard.',
#  'Governments worldwide are investing in infrastructure to support new transport methods. Gun small thought. Himself hot it positive. Budget us family how. Old animal there trip consider east then. Fear event thus worry say certain ground. Share fish meeting item during policy.\n\nGovernments worldwide are investing in infrastructure to support new transport methods. However around want station. Spend physical knowledge language believe. Stuff participant total stuff.',
#  'In ancient times, transportation was limited to walking and animal domestication. Million already billion magazine. Lay appear offer important. Family go where research all south doctor. Safe join news chair still situation.',
#  'Sustainable transportation is becoming increasingly important in the fight against climate change. Tough step color follow. Care security all in choose treatment hope. Difficult technology member adult magazine. If water agent make travel sea office wide. Window scene the care.\n\nHigh-speed trains and subways reshaped urban transportation. Second order close structure recent woman opportunity. Seek return establish order. Weight since same find box list first.',
#  'The invention of the wheel revolutionized human movement. Important mean almost because. Clear family common threat gun model. Establish again ahead including. Despite network perhaps after force pass six surface. Their station save soon well.',
#  'Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Already these growth never machine child quite. Responsibility news knowledge employee institution end. Tree crime still reflect eight. Skin these these laugh each value little. Sort important determine within fund. Policy trip place tough.',
#  'Today, electric vehicles and autonomous cars represent a new era of mobility. Beautiful year key relate. Debate police agency hope common thought half. Me protect toward ok trade dinner difference. Trip recognize add ok prove. Build firm book. Anyone often particularly security claim.',
#  'Today, electric vehicles and autonomous cars represent a new era of mobility. Education federal after skin her. Two speech head yeah. Although country relationship bit. Production form television true. Short decide management trial.\n\nDuring the Industrial Revolution, steam engines transformed both land and sea travel. Audience throughout win way. Cold nearly enjoy nearly time reach. Seek argue painting bed much.',
#  'Today, electric vehicles and autonomous cars represent a new era of mobility. Need contain step herself human. Number pull mother carry painting nature. Mention whole with do myself. Site item wonder by. City future several former face office system. Fast also decision stage.',
#  'Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Number both morning light nation position. Staff training left after. In ago any response. Everybody onto sing nearly family issue. Agency close compare eight lose. During owner check attorney process.']

# %%
# Step 5: Create custom embedding class using requests
class CustomEmbedding(Embeddings):
    def embed_documents(self, texts):
        url = "http://localhost:11434/v1/embeddings"
        headers = {"Content-Type": "application/json"}
        data = {
            "model": "mxbai-embed-large:latest",
            "input": texts
        }
        response = requests.post(url, headers=headers, json=data)
        response.raise_for_status()
        return [d["embedding"] for d in response.json()["data"]]
    
    def embed_query(self, text):
        return self.embed_documents([text])[0]

embedding_model = CustomEmbedding()

# %%
# Step 6: Store in Chroma DB
persist_directory = "chroma_db"

# %%
print(Embeddings)
# Out:
# <class 'langchain_core.embeddings.embeddings.Embeddings'>

# %%
# Step 7: Create Chroma vector store and persist
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    persist_directory=persist_directory
)

vectorstore.persist()
print("✅ Embeddings stored successfully in Chroma DB.")
# Out:
# ✅ Embeddings stored successfully in Chroma DB.
# C:\Users\SreeKeerthiReddyThat\AppData\Local\Temp\ipykernel_21100\22586813.py:8: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %%
# Explicitly request embeddings, metadata, and documents
results = vectorstore.get(include=["embeddings", "metadatas", "documents"])

# Print each chunk and its embedding
for i, (embedding, metadata, document) in enumerate(zip(results["embeddings"], results["metadatas"], results["documents"])):
    print(f"\n🔹 Chunk {i+1}:")
    print(f"Text: {document[:100]}...")  # Print first 100 characters of the chunk
    print(f"Embedding: {embedding[:5]}...")  # Print first 5 dimensions for brevity
# Out:
# 🔹 Chunk 1:
# Text: The invention of the wheel revolutionized human movement. American whole magazine truth stop whose. ...
# Embedding: [ 0.00135405 -0.00638477  0.02167933  0.0439051   0.01640437]...
#
# 🔹 Chunk 2:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Kind miss ar...
# Embedding: [ 0.01892734 -0.01751047  0.02744835  0.00064038  0.00643887]...
#
# 🔹 Chunk 3:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Attorney quickly candi...
# Embedding: [ 0.01401016  0.00997913 -0.00108978  0.02315456  0.00525275]...
#
# 🔹 Chunk 4:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Decision so...
# Embedding: [ 0.02067159  0.00056219 -0.00738473  0.00110476  0.00992023]...
#
# 🔹 Chunk 5:
# Text: High-speed trains and subways reshaped urban transportation. Exactly drive well good explain grow wa...
# Embedding: [ 0.01034095  0.00454821 -0.00739463  0.00665863 -0.01190622]...
#
# 🔹 Chunk 6:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Physical again...
# Embedding: [-0.01013022  0.0152913   0.03000627 -0.02689739  0.00873518]...
#
# 🔹 Chunk 7:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [0.02710649 0.04063169 0.00030573 0.01783803 0.01118263]...
#
# 🔹 Chunk 8:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Institution ...
# Embedding: [ 0.00859615 -0.01788422  0.00863766  0.03537644 -0.01225005]...
#
# 🔹 Chunk 9:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. P...
# Embedding: [ 0.01032474  0.05951204 -0.02530056  0.01073758  0.00561421]...
#
# 🔹 Chunk 10:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Technology song than l...
# Embedding: [ 0.01545037 -0.00312915  0.00385527  0.01402903  0.01529741]...
#
# 🔹 Chunk 11:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [ 0.03957947 -0.00212144  0.0008352  -0.00504253  0.01534999]...
#
# 🔹 Chunk 12:
# Text: High-speed trains and subways reshaped urban transportation. Crime situation since book art red. Pla...
# Embedding: [0.01734441 0.00097032 0.02220173 0.02951219 0.02361661]...
#
# 🔹 Chunk 13:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Medical watc...
# Embedding: [-0.01656478 -0.00311965  0.0249093  -0.01780729  0.01421725]...
#
# 🔹 Chunk 14:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Player contain...
# Embedding: [-0.03287061  0.00854697  0.03114654 -0.04174445  0.00451194]...
#
# 🔹 Chunk 15:
# Text: In ancient times, transportation was limited to walking and animal domestication. Fear great easy pl...
# Embedding: [ 0.04154009  0.0069941   0.01658453 -0.01609668  0.01850813]...
#
# 🔹 Chunk 16:
# Text: In ancient times, transportation was limited to walking and animal domestication. Set discussion sev...
# Embedding: [0.06350676 0.0264297  0.01513552 0.00562692 0.00901803]...
#
# 🔹 Chunk 17:
# Text: The 20th century saw the rise of automobiles and airplanes. Scientist tough everything kind nothing ...
# Embedding: [-0.00665252  0.00825622  0.04259735  0.00524029  0.00480471]...
#
# 🔹 Chunk 18:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Guess break ...
# Embedding: [ 0.01665775  0.02652714 -0.01985754  0.03266746 -0.00232584]...
#
# 🔹 Chunk 19:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Report town...
# Embedding: [ 0.0330526   0.00115437 -0.01852984  0.00819488  0.00500499]...
#
# 🔹 Chunk 20:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. About pressu...
# Embedding: [ 0.04320978  0.02262346  0.03488009 -0.00216891 -0.00566406]...
#
# 🔹 Chunk 21:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Where economic detail....
# Embedding: [ 0.02037243  0.00699025 -0.03065869  0.0076532  -0.0196282 ]...
#
# 🔹 Chunk 22:
# Text: The invention of the wheel revolutionized human movement. Case administration measure happen. Speech...
# Embedding: [ 0.01087756 -0.00297447  0.01151642  0.01282349  0.01043388]...
#
# 🔹 Chunk 23:
# Text: The 20th century saw the rise of automobiles and airplanes. Region bad case I course first. Himself ...
# Embedding: [ 0.00396031  0.01124496  0.03331418  0.00762268 -0.00708194]...
#
# 🔹 Chunk 24:
# Text: In ancient times, transportation was limited to walking and animal domestication. North but west. Ab...
# Embedding: [ 0.02983807  0.00762941  0.01412852  0.00320008 -0.01910503]...
#
# 🔹 Chunk 25:
# Text: The invention of the wheel revolutionized human movement. Several might history strong economy. Not ...
# Embedding: [ 0.02291865  0.00449816  0.0082826   0.01244083 -0.00946319]...
#
# 🔹 Chunk 26:
# Text: High-speed trains and subways reshaped urban transportation. Find add sing standard exactly. Mrs nev...
# Embedding: [-0.00684631 -0.01721914  0.03977426  0.03675831 -0.01488476]...
#
# 🔹 Chunk 27:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Action economy...
# Embedding: [-0.01504395  0.00032424  0.03692569 -0.02572586  0.00387482]...
#
# 🔹 Chunk 28:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Wear general...
# Embedding: [0.00592012 0.00264144 0.00953296 0.04433871 0.00541789]...
#
# 🔹 Chunk 29:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Later street mention w...
# Embedding: [ 0.03123564  0.01035354 -0.0121395   0.02183039  0.0051933 ]...
#
# 🔹 Chunk 30:
# Text: The 20th century saw the rise of automobiles and airplanes. Where a front war receive. Company TV po...
# Embedding: [ 0.01856102  0.01612486  0.02559228  0.02878076 -0.01715788]...
#
# 🔹 Chunk 31:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Head against particula...
# Embedding: [0.01741394 0.0339983  0.02390708 0.02903032 0.01476544]...
#
# 🔹 Chunk 32:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Risk catch check clear...
# Embedding: [ 0.00059894  0.0061745  -0.02887046  0.01331419 -0.01610162]...
#
# 🔹 Chunk 33:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Blood single r...
# Embedding: [-0.01050555  0.01579139  0.04418492  0.01602879 -0.0134087 ]...
#
# 🔹 Chunk 34:
# Text: The invention of the wheel revolutionized human movement. Popular if do them. Lose big strategy. Nea...
# Embedding: [ 0.01092814  0.009287   -0.00965585  0.01094413 -0.00831182]...
#
# 🔹 Chunk 35:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Great weste...
# Embedding: [ 0.04641478 -0.01516347  0.00380911 -0.00591277  0.01114186]...
#
# 🔹 Chunk 36:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. F...
# Embedding: [0.03135369 0.05454789 0.00286939 0.05257638 0.00818571]...
#
# 🔹 Chunk 37:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Unit dinner...
# Embedding: [ 0.01749396 -0.02427198 -0.01043934  0.02902098 -0.00031827]...
#
# 🔹 Chunk 38:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Can effort bad...
# Embedding: [-0.03649027  0.00620465  0.02696783 -0.03179351 -0.01017576]...
#
# 🔹 Chunk 39:
# Text: In ancient times, transportation was limited to walking and animal domestication. Could foreign mind...
# Embedding: [ 0.01986704  0.00403129  0.01939112 -0.0071887   0.01497106]...
#
# 🔹 Chunk 40:
# Text: In ancient times, transportation was limited to walking and animal domestication. Hospital wrong fis...
# Embedding: [ 0.04452832 -0.00435592  0.0241381  -0.01474819 -0.00698089]...
#
# 🔹 Chunk 41:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Station enough become ...
# Embedding: [ 0.03045688  0.00502043 -0.00155125  0.03349259  0.0316801 ]...
#
# 🔹 Chunk 42:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Yet really which human...
# Embedding: [ 0.03032649  0.03398637 -0.01488264  0.01179942 -0.01490438]...
#
# 🔹 Chunk 43:
# Text: High-speed trains and subways reshaped urban transportation. Company drop join recognize all structu...
# Embedding: [ 0.01796937 -0.01521986  0.03202607  0.03622484 -0.00942456]...
#
# 🔹 Chunk 44:
# Text: In ancient times, transportation was limited to walking and animal domestication. Air ball better co...
# Embedding: [0.04101714 0.02980621 0.01105216 0.01256565 0.00918656]...
#
# 🔹 Chunk 45:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Late every include gen...
# Embedding: [ 0.01564493  0.01929698 -0.01312992  0.01609978  0.00129967]...
#
# 🔹 Chunk 46:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Smile creat...
# Embedding: [0.03281455 0.00541195 0.002243   0.02567124 0.03139791]...
#
# 🔹 Chunk 47:
# Text: The invention of the wheel revolutionized human movement. Evening scene that himself floor somebody ...
# Embedding: [ 0.01168964  0.00031366  0.01385987  0.0179572  -0.00817137]...
#
# 🔹 Chunk 48:
# Text: The 20th century saw the rise of automobiles and airplanes. Part instead city type short rather. Onc...
# Embedding: [-0.01214391  0.01810784  0.06787446 -0.00409586 -0.02418566]...
#
# 🔹 Chunk 49:
# Text: In ancient times, transportation was limited to walking and animal domestication. See different deci...
# Embedding: [0.02422148 0.00322741 0.03227796 0.00266658 0.00102591]...
#
# 🔹 Chunk 50:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Voice boy forward scie...
# Embedding: [ 0.02574064  0.02734374 -0.00448741  0.00998215  0.0203305 ]...
#
# 🔹 Chunk 51:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Level gener...
# Embedding: [ 0.01533446  0.00495567  0.01462035 -0.00049756  0.01933352]...
#
# 🔹 Chunk 52:
# Text: High-speed trains and subways reshaped urban transportation. Mention hot happy far. Effort drop onto...
# Embedding: [-0.0046944   0.01405798  0.01769429  0.02555199 -0.01840921]...
#
# 🔹 Chunk 53:
# Text: The 20th century saw the rise of automobiles and airplanes. Tell boy arrive. Several past next final...
# Embedding: [ 0.01584681  0.00869239  0.03725192  0.0097416  -0.00043126]...
#
# 🔹 Chunk 54:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Goal probab...
# Embedding: [ 0.03589366 -0.01898164  0.00630865  0.00932456  0.00788249]...
#
# 🔹 Chunk 55:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Box operatio...
# Embedding: [ 0.03937767  0.02336198  0.04468286  0.03722329 -0.02856412]...
#
# 🔹 Chunk 56:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Over ten tree pull lik...
# Embedding: [ 0.0252867   0.01590184 -0.01405719  0.03743102 -0.00209513]...
#
# 🔹 Chunk 57:
# Text: High-speed trains and subways reshaped urban transportation. House central baby picture choice could...
# Embedding: [ 0.00640651  0.00781298  0.02451759  0.02000117 -0.01300726]...
#
# 🔹 Chunk 58:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Civil market value dur...
# Embedding: [0.01211476 0.01627905 0.0071454  0.0086737  0.00395645]...
#
# 🔹 Chunk 59:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Member sign life succe...
# Embedding: [-0.00303409  0.01556161 -0.01479806  0.03418414  0.02503243]...
#
# 🔹 Chunk 60:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Administrati...
# Embedding: [ 0.02133231  0.01017572  0.01670065  0.0280281  -0.00319302]...
#
# 🔹 Chunk 61:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Relate number night ad...
# Embedding: [3.17917913e-02 1.45056387e-02 7.47618833e-05 3.15341428e-02
#  7.81726278e-03]...
#
# 🔹 Chunk 62:
# Text: The 20th century saw the rise of automobiles and airplanes. Activity note attention yeah process res...
# Embedding: [-0.00284975  0.01669067  0.03439831  0.02109394 -0.01773831]...
#
# 🔹 Chunk 63:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Physical play ...
# Embedding: [-0.02300419  0.00780155  0.03686797 -0.02617365  0.00354631]...
#
# 🔹 Chunk 64:
# Text: High-speed trains and subways reshaped urban transportation. Face key when also. Citizen to produce ...
# Embedding: [ 0.02103886 -0.0011416   0.01458336  0.02421782 -0.01204676]...
#
# 🔹 Chunk 65:
# Text: High-speed trains and subways reshaped urban transportation. When room network behind social her he....
# Embedding: [-0.00442829  0.00795173  0.01043982  0.04289033  0.00672974]...
#
# 🔹 Chunk 66:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. W...
# Embedding: [0.00334015 0.04404609 0.01266618 0.00190478 0.00194587]...
#
# 🔹 Chunk 67:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Plant color current no...
# Embedding: [-0.0031564  -0.00159657 -0.01183798  0.02290569  0.00789284]...
#
# 🔹 Chunk 68:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Share address than cou...
# Embedding: [ 0.00650673  0.00121898  0.00100273  0.01217515 -0.01057126]...
#
# 🔹 Chunk 69:
# Text: The 20th century saw the rise of automobiles and airplanes. Beat sometimes Republican agent manage s...
# Embedding: [0.01646647 0.01123776 0.02514665 0.0188732  0.0198627 ]...
#
# 🔹 Chunk 70:
# Text: The 20th century saw the rise of automobiles and airplanes. Fill can cause as. Create agree likely o...
# Embedding: [-0.01383472  0.0428497   0.06304392 -0.01313708 -0.01592597]...
#
# 🔹 Chunk 71:
# Text: High-speed trains and subways reshaped urban transportation. Speak let guy son. Gas class wish relat...
# Embedding: [ 0.00060902 -0.00290987  0.01046217  0.01832111 -0.00325969]...
#
# 🔹 Chunk 72:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Place strong parent be...
# Embedding: [-0.00967644 -0.00141954  0.00555993 -0.00439511  0.01084874]...
#
# 🔹 Chunk 73:
# Text: The 20th century saw the rise of automobiles and airplanes. Operation point loss mean production est...
# Embedding: [-0.00553122  0.0129007   0.01511583  0.03469853 -0.02286858]...
#
# 🔹 Chunk 74:
# Text: In ancient times, transportation was limited to walking and animal domestication. Rest others develo...
# Embedding: [ 0.03493589  0.03697083  0.00337668 -0.00910505 -0.00662269]...
#
# 🔹 Chunk 75:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. U...
# Embedding: [ 0.00181716  0.04429856  0.00214767 -0.0194149   0.00754326]...
#
# 🔹 Chunk 76:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. C...
# Embedding: [ 0.0244045   0.05192607 -0.00927821  0.01797803  0.01004338]...
#
# 🔹 Chunk 77:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Social per civil. Same...
# Embedding: [0.01755009 0.01411434 0.00926731 0.04411989 0.0190275 ]...
#
# 🔹 Chunk 78:
# Text: In ancient times, transportation was limited to walking and animal domestication. Kitchen mind wife ...
# Embedding: [ 0.04705589  0.0009751   0.01132399  0.00247212 -0.02447801]...
#
# 🔹 Chunk 79:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Economic att...
# Embedding: [ 0.00217993  0.0182313  -0.011056    0.0041718   0.0098821 ]...
#
# 🔹 Chunk 80:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. It start no...
# Embedding: [ 0.01679288 -0.0061792  -0.01496638  0.0144983   0.00656139]...
#
# 🔹 Chunk 81:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Other quest...
# Embedding: [ 0.01759372 -0.01935459  0.02294608  0.0401215   0.01764129]...
#
# 🔹 Chunk 82:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Book they fiel...
# Embedding: [-0.01093816  0.02375851  0.03238443 -0.02493139  0.00936203]...
#
# 🔹 Chunk 83:
# Text: High-speed trains and subways reshaped urban transportation. Feel beat why matter instead need confe...
# Embedding: [ 0.02364915 -0.00214977  0.00611251  0.05021822 -0.01599673]...
#
# 🔹 Chunk 84:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Not identify score. Ha...
# Embedding: [ 0.01602666  0.0052108  -0.01988497  0.0159088  -0.00186412]...
#
# 🔹 Chunk 85:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Decade plant identify ...
# Embedding: [ 0.01152404 -0.00146876 -0.00367877  0.0267028   0.00978158]...
#
# 🔹 Chunk 86:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Prevent new...
# Embedding: [ 0.01145666  0.0116814  -0.00583879  0.00267936  0.02493654]...
#
# 🔹 Chunk 87:
# Text: The 20th century saw the rise of automobiles and airplanes. Media successful anyone candidate defens...
# Embedding: [-0.00068188  0.02257611  0.03807098  0.03779644  0.00408962]...
#
# 🔹 Chunk 88:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.00810609  0.03390926 -0.01524146  0.01682171  0.01192944]...
#
# 🔹 Chunk 89:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Space store ...
# Embedding: [0.00122482 0.00812037 0.00160893 0.05047002 0.01416797]...
#
# 🔹 Chunk 90:
# Text: In ancient times, transportation was limited to walking and animal domestication. Soon four once ent...
# Embedding: [ 0.01353897  0.02971156  0.03801423 -0.03713699  0.00973546]...
#
# 🔹 Chunk 91:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Half importa...
# Embedding: [-0.00718313 -0.0101809  -0.00325261  0.00949943 -0.00630479]...
#
# 🔹 Chunk 92:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Embedding: [ 0.01764813 -0.00877199  0.00286054  0.01826868  0.02234158]...
#
# 🔹 Chunk 93:
# Text: High-speed trains and subways reshaped urban transportation. Current by write north product well sch...
# Embedding: [ 0.00286829 -0.03099594  0.01867948  0.01721779 -0.01148152]...
#
# 🔹 Chunk 94:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Call various...
# Embedding: [0.03335737 0.02169948 0.00957457 0.02269132 0.01241124]...
#
# 🔹 Chunk 95:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Hit half agreement spe...
# Embedding: [0.01887314 0.00705545 0.00761925 0.01218661 0.02407484]...
#
# 🔹 Chunk 96:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Deep anythi...
# Embedding: [ 0.01250027 -0.00937822 -0.00013767  0.00285409  0.01640946]...
#
# 🔹 Chunk 97:
# Text: The 20th century saw the rise of automobiles and airplanes. Identify involve hospital capital others...
# Embedding: [0.01952354 0.00989266 0.03362218 0.01203185 0.02404428]...
#
# 🔹 Chunk 98:
# Text: High-speed trains and subways reshaped urban transportation. Ready the theory moment better of music...
# Embedding: [-0.02337343 -0.00352904  0.0388845  -0.02054176 -0.01671087]...
#
# 🔹 Chunk 99:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Others sort fo...
# Embedding: [-0.00805014 -0.00958581  0.02795397  0.00239695  0.0001035 ]...
#
# 🔹 Chunk 100:
# Text: In ancient times, transportation was limited to walking and animal domestication. Hope current page....
# Embedding: [ 0.04619366  0.03939649  0.04582964 -0.00906708 -0.01791854]...
#
# 🔹 Chunk 101:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. G...
# Embedding: [-0.0023846   0.01927193  0.00322986 -0.00306807 -0.01201701]...
#
# 🔹 Chunk 102:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [-0.00142482  0.01874286 -0.00808824  0.02043053  0.03029315]...
#
# 🔹 Chunk 103:
# Text: The invention of the wheel revolutionized human movement. When general everything center wind note n...
# Embedding: [-0.02339034  0.00764162  0.02444959 -0.04096855  0.01187676]...
#
# 🔹 Chunk 104:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Forget crime r...
# Embedding: [-0.01210557  0.00814977  0.0326561  -0.01725802 -0.00103051]...
#
# 🔹 Chunk 105:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Become lead...
# Embedding: [ 0.00496482 -0.03395941 -0.00566701 -0.00816338  0.02649047]...
#
# 🔹 Chunk 106:
# Text: The 20th century saw the rise of automobiles and airplanes. Prevent manage line. Range happen look a...
# Embedding: [-0.02421213  0.01352752  0.04033504 -0.0003384  -0.01785848]...
#
# 🔹 Chunk 107:
# Text: The 20th century saw the rise of automobiles and airplanes. Traditional probably article last forwar...
# Embedding: [0.00827118 0.04324884 0.02095649 0.01198842 0.00182626]...
#
# 🔹 Chunk 108:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Door admit visit again...
# Embedding: [ 0.02626335  0.03419691 -0.01556152  0.02630091 -0.00512115]...
#
# 🔹 Chunk 109:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Game which sto...
# Embedding: [-0.00438841  0.00065215  0.04251147 -0.00647971  0.00869688]...
#
# 🔹 Chunk 110:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Quality pro...
# Embedding: [ 0.03175918 -0.00087328  0.01234225  0.02782521  0.03711044]...
#
# 🔹 Chunk 111:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Account reason sure ac...
# Embedding: [ 0.00223445  0.00634137 -0.0239439   0.00807533  0.01322997]...
#
# 🔹 Chunk 112:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Concern wor...
# Embedding: [ 0.01086435 -0.02242698 -0.00382877  0.01999187  0.00736547]...
#
# 🔹 Chunk 113:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Magazine paper age phy...
# Embedding: [0.02039408 0.00242891 0.00867894 0.01640816 0.01326888]...
#
# 🔹 Chunk 114:
# Text: In ancient times, transportation was limited to walking and animal domestication. Tonight woman driv...
# Embedding: [0.0191534  0.06648143 0.01416508 0.00055654 0.010098  ]...
#
# 🔹 Chunk 115:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. M...
# Embedding: [0.06100725 0.05338929 0.00804091 0.01944676 0.00399611]...
#
# 🔹 Chunk 116:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Could number for as hi...
# Embedding: [ 0.00212298  0.01113734 -0.00769884 -0.00806746 -0.00543861]...
#
# 🔹 Chunk 117:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.01432353  0.05529489  0.00684418 -0.0016096   0.00208176]...
#
# 🔹 Chunk 118:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Team front mother poss...
# Embedding: [ 0.02022926  0.02083773 -0.0332002   0.01208635 -0.00198642]...
#
# 🔹 Chunk 119:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Dinner both in sea res...
# Embedding: [ 0.00782579  0.02250655 -0.01646447  0.00049735 -0.00080942]...
#
# 🔹 Chunk 120:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Country tow...
# Embedding: [ 0.03626595 -0.01095205  0.01050314  0.01379833  0.00214509]...
#
# 🔹 Chunk 121:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Social examp...
# Embedding: [-0.001962    0.00600956 -0.00628864  0.02023999  0.02453626]...
#
# 🔹 Chunk 122:
# Text: The 20th century saw the rise of automobiles and airplanes. Crime thank mean edge among direction. S...
# Embedding: [-0.00164933  0.03593979  0.0336038   0.0415532  -0.03139539]...
#
# 🔹 Chunk 123:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Education answer blood...
# Embedding: [ 0.01648489  0.02022207 -0.00808012  0.01844695  0.02744084]...
#
# 🔹 Chunk 124:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Size worry ...
# Embedding: [ 0.05044487 -0.00327398  0.01260192  0.02682239  0.02855976]...
#
# 🔹 Chunk 125:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Talk ago green...
# Embedding: [-0.05078843  0.01370989  0.03616673 -0.02998482 -0.01262825]...
#
# 🔹 Chunk 126:
# Text: In ancient times, transportation was limited to walking and animal domestication. Practice yes kind ...
# Embedding: [ 0.02804125  0.03759567  0.03110993  0.00539453 -0.01231349]...
#
# 🔹 Chunk 127:
# Text: High-speed trains and subways reshaped urban transportation. Stop law you well else candidate relati...
# Embedding: [ 0.01656347  0.02051693  0.03546134  0.01334403 -0.02410349]...
#
# 🔹 Chunk 128:
# Text: High-speed trains and subways reshaped urban transportation. Home yard give film question record. La...
# Embedding: [ 0.00404559 -0.01715502  0.03699593  0.02190899  0.00756236]...
#
# 🔹 Chunk 129:
# Text: The 20th century saw the rise of automobiles and airplanes. Class game may television sense. Animal ...
# Embedding: [0.02305428 0.02141379 0.03867211 0.02266415 0.00733686]...
#
# 🔹 Chunk 130:
# Text: In ancient times, transportation was limited to walking and animal domestication. Behind section rat...
# Embedding: [ 5.51789664e-02  4.13591834e-03  4.59835120e-02  3.57682948e-05
#  -1.95224304e-02]...
#
# 🔹 Chunk 131:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. What discuss campaign ...
# Embedding: [0.02184725 0.05019384 0.01740206 0.01699844 0.01725678]...
#
# 🔹 Chunk 132:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Health good commercial...
# Embedding: [ 0.00491794  0.00979169 -0.01028273  0.0189352  -0.00724908]...
#
# 🔹 Chunk 133:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Produce decision dinne...
# Embedding: [ 0.0236522   0.01676001 -0.00012713  0.03796623  0.02113018]...
#
# 🔹 Chunk 134:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. That thing owner where...
# Embedding: [ 0.0092324  -0.01875326 -0.01995671  0.01523625  0.02873464]...
#
# 🔹 Chunk 135:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Drug probabl...
# Embedding: [ 0.01048125 -0.01311716  0.0106995   0.0084283   0.01190628]...
#
# 🔹 Chunk 136:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Pressure ball financia...
# Embedding: [ 0.01038751  0.00982841 -0.00869197  0.00193772 -0.0055791 ]...
#
# 🔹 Chunk 137:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. We later arrive child....
# Embedding: [-0.00156517  0.00881165 -0.01066471 -0.0153444   0.01402547]...
#
# 🔹 Chunk 138:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. K...
# Embedding: [0.00700701 0.04079218 0.00166535 0.01631842 0.00418497]...
#
# 🔹 Chunk 139:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Boy while to...
# Embedding: [0.00587152 0.03450105 0.00502999 0.00278489 0.00659922]...
#
# 🔹 Chunk 140:
# Text: The invention of the wheel revolutionized human movement. Light film cell effort gun. Instead specif...
# Embedding: [ 0.02573465 -0.00155675  0.00296704  0.00578587  0.00752609]...
#
# 🔹 Chunk 141:
# Text: In ancient times, transportation was limited to walking and animal domestication. Green together int...
# Embedding: [ 0.05694081  0.02285983  0.01761263 -0.00251171 -0.02664263]...
#
# 🔹 Chunk 142:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Thousand season progra...
# Embedding: [ 0.00737643  0.01327211 -0.00976155  0.02814642  0.03809311]...
#
# 🔹 Chunk 143:
# Text: The 20th century saw the rise of automobiles and airplanes. Red however draw ten reflect. Price trou...
# Embedding: [ 0.0091231   0.03323423  0.00877705 -0.00829168  0.00430265]...
#
# 🔹 Chunk 144:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Him local sing...
# Embedding: [-0.00671378 -0.00322587  0.01188125 -0.02522677  0.0158673 ]...
#
# 🔹 Chunk 145:
# Text: The invention of the wheel revolutionized human movement. Population process future else establish p...
# Embedding: [-0.00230328  0.00920659  0.02479174  0.0037978   0.00029428]...
#
# 🔹 Chunk 146:
# Text: The invention of the wheel revolutionized human movement. Just within threat. Physical who establish...
# Embedding: [ 0.04753664  0.02156864 -0.00961098  0.01609055 -0.04208924]...
#
# 🔹 Chunk 147:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [-0.00071647  0.06723276  0.00384819  0.0259508   0.00221841]...
#
# 🔹 Chunk 148:
# Text: In ancient times, transportation was limited to walking and animal domestication. Professional ident...
# Embedding: [ 0.02089796  0.04496919  0.01589135  0.00558983 -0.00033414]...
#
# 🔹 Chunk 149:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Try wait side part wes...
# Embedding: [ 0.00278858  0.01108915  0.01884811 -0.02566858  0.00935431]...
#
# 🔹 Chunk 150:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Plan your pa...
# Embedding: [ 0.00753642 -0.00709374 -0.01229759  0.0398423   0.027069  ]...
#
# 🔹 Chunk 151:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Cut product...
# Embedding: [ 0.01537674 -0.02689081 -0.0075088   0.01668818  0.01930979]...
#
# 🔹 Chunk 152:
# Text: High-speed trains and subways reshaped urban transportation. Decision assume successful. Marriage pe...
# Embedding: [ 0.01600401 -0.00742408  0.01147352  0.00231384 -0.0216101 ]...
#
# 🔹 Chunk 153:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Amount natio...
# Embedding: [0.03598719 0.0209609  0.04941085 0.02726529 0.00571616]...
#
# 🔹 Chunk 154:
# Text: The invention of the wheel revolutionized human movement. Image him soldier suddenly myself imagine ...
# Embedding: [-0.00750209  0.02444375  0.00536434 -0.00253377 -0.01124981]...
#
# 🔹 Chunk 155:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Threat hous...
# Embedding: [0.01827643 0.01037451 0.00105235 0.01933244 0.01729224]...
#
# 🔹 Chunk 156:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Concern toward fast sp...
# Embedding: [1.84104101e-05 1.64721403e-02 3.04433797e-03 1.89770944e-02
#  7.22474186e-03]...
#
# 🔹 Chunk 157:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Heart that American li...
# Embedding: [ 0.02851938  0.00513923 -0.02044771  0.04839508  0.01963439]...
#
# 🔹 Chunk 158:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. American need outside ...
# Embedding: [-0.00069169  0.02041925 -0.01496213  0.00955238  0.00859411]...
#
# 🔹 Chunk 159:
# Text: High-speed trains and subways reshaped urban transportation. Firm phone conference someone relate. P...
# Embedding: [ 0.01599281 -0.00351692  0.00206683  0.03583451 -0.01223455]...
#
# 🔹 Chunk 160:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Marriage gro...
# Embedding: [-0.00659858  0.00649627  0.00068199  0.00834672  0.01047021]...
#
# 🔹 Chunk 161:
# Text: The 20th century saw the rise of automobiles and airplanes. Where Mrs above husband. Southern size r...
# Embedding: [ 0.00569319  0.03745851  0.05092549  0.00527619 -0.01437058]...
#
# 🔹 Chunk 162:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. C...
# Embedding: [ 0.01938909  0.03621551 -0.0175213  -0.00184171  0.00394057]...
#
# 🔹 Chunk 163:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Especially writer air ...
# Embedding: [ 0.00964246  0.0097872  -0.007796    0.01453749  0.0327025 ]...
#
# 🔹 Chunk 164:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01378673  0.03362676 -0.00376769  0.01440501 -0.00698317]...
#
# 🔹 Chunk 165:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Will your appr...
# Embedding: [ 0.0015249   0.02341338  0.02439686 -0.01068136 -0.00498998]...
#
# 🔹 Chunk 166:
# Text: High-speed trains and subways reshaped urban transportation. Effect message west take black impact h...
# Embedding: [-0.02716265 -0.01200727  0.03540753  0.04139767 -0.01270721]...
#
# 🔹 Chunk 167:
# Text: The 20th century saw the rise of automobiles and airplanes. Evidence something really manage read th...
# Embedding: [ 0.00587068  0.01826657  0.04395685  0.01301811 -0.01260765]...
#
# 🔹 Chunk 168:
# Text: High-speed trains and subways reshaped urban transportation. Quickly foot star. Movie present people...
# Embedding: [ 0.01223859 -0.00159237  0.00389048  0.01152543 -0.01064716]...
#
# 🔹 Chunk 169:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Company many agency sh...
# Embedding: [-1.81838677e-05 -8.80145375e-03  1.06223812e-02  2.57002115e-02
#   2.59329248e-02]...
#
# 🔹 Chunk 170:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Least sort rise actual...
# Embedding: [0.01460422 0.00887088 0.01470595 0.00165328 0.03011917]...
#
# 🔹 Chunk 171:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Bill both after analys...
# Embedding: [-0.01461958  0.02279857 -0.01185588  0.00426819 -0.00955606]...
#
# 🔹 Chunk 172:
# Text: The invention of the wheel revolutionized human movement. Increase concern pressure. Treat push firs...
# Embedding: [ 0.02986271  0.01445072  0.01910432  0.02529137 -0.01774891]...
#
# 🔹 Chunk 173:
# Text: The invention of the wheel revolutionized human movement. Stock story glass employee listen require ...
# Embedding: [-0.00405313 -0.00291416 -0.01298771  0.01830394 -0.010227  ]...
#
# 🔹 Chunk 174:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Nothing course claim u...
# Embedding: [ 0.02760874  0.04007047  0.00576227  0.00471083 -0.00492599]...
#
# 🔹 Chunk 175:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Drop use dream...
# Embedding: [-0.02578749  0.00323587  0.02297177 -0.03377908  0.00352771]...
#
# 🔹 Chunk 176:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Later image...
# Embedding: [ 0.02100461 -0.00669769  0.01428407 -0.01098064  0.01822886]...
#
# 🔹 Chunk 177:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [0.00208138 0.06380757 0.02403099 0.01188998 0.00720604]...
#
# 🔹 Chunk 178:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Not nor leg sister oil...
# Embedding: [-0.00384633  0.01118418 -0.01522246  0.0155482  -0.01398379]...
#
# 🔹 Chunk 179:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Art director herself t...
# Embedding: [-0.00937301 -0.00437298 -0.00590195  0.00423368  0.01180463]...
#
# 🔹 Chunk 180:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Mean approac...
# Embedding: [ 0.00594353  0.02044763 -0.03765455 -0.01220966  0.00073344]...
#
# 🔹 Chunk 181:
# Text: The 20th century saw the rise of automobiles and airplanes. Language indeed bring account candidate....
# Embedding: [0.01607317 0.037135   0.02855582 0.02085264 0.00508406]...
#
# 🔹 Chunk 182:
# Text: High-speed trains and subways reshaped urban transportation. Student plan among relate decade. Succe...
# Embedding: [ 0.0077704  -0.03766566  0.00386248  0.03635035 -0.01294966]...
#
# 🔹 Chunk 183:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Institution agency whi...
# Embedding: [0.00425287 0.01165391 0.00807935 0.01610629 0.0101204 ]...
#
# 🔹 Chunk 184:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Always foll...
# Embedding: [ 0.03941456 -0.00826544  0.03377967  0.01011353  0.01849943]...
#
# 🔹 Chunk 185:
# Text: In ancient times, transportation was limited to walking and animal domestication. Market voice art b...
# Embedding: [ 0.03489449  0.0321203   0.02313478 -0.01113732  0.00372687]...
#
# 🔹 Chunk 186:
# Text: In ancient times, transportation was limited to walking and animal domestication. Capital product op...
# Embedding: [ 0.02595499  0.04343992  0.04118977 -0.02162056  0.00280116]...
#
# 🔹 Chunk 187:
# Text: In ancient times, transportation was limited to walking and animal domestication. Up charge else tha...
# Embedding: [ 0.00552532  0.02421744  0.00670002  0.00434224 -0.00178567]...
#
# 🔹 Chunk 188:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Try indeed ...
# Embedding: [ 0.02615775  0.02073991  0.03360014  0.00536272 -0.00852831]...
#
# 🔹 Chunk 189:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Design whet...
# Embedding: [-0.01564878 -0.02481084  0.02837843 -0.0218144   0.0110542 ]...
#
# 🔹 Chunk 190:
# Text: In ancient times, transportation was limited to walking and animal domestication. Beat lay plan face...
# Embedding: [ 0.0306678   0.00986767  0.02530866 -0.00401896  0.01242309]...
#
# 🔹 Chunk 191:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Along could carry espe...
# Embedding: [-0.00185704  0.04067458 -0.02954891 -0.01417173 -0.02185405]...
#
# 🔹 Chunk 192:
# Text: The 20th century saw the rise of automobiles and airplanes. War word if light alone represent develo...
# Embedding: [ 0.0221498   0.02394677  0.0348579   0.01862453 -0.02315615]...
#
# 🔹 Chunk 193:
# Text: In ancient times, transportation was limited to walking and animal domestication. Four into lay game...
# Embedding: [ 0.02978138  0.02132136  0.04728809 -0.00152715 -0.02731396]...
#
# 🔹 Chunk 194:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Tax force orde...
# Embedding: [-0.03121676 -0.00185463  0.03345324 -0.00757323  0.00107144]...
#
# 🔹 Chunk 195:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Throw step ...
# Embedding: [ 0.00468764 -0.00575677  0.02040019 -0.0143538   0.00845098]...
#
# 🔹 Chunk 196:
# Text: High-speed trains and subways reshaped urban transportation. Effort station by. Foot face pay custom...
# Embedding: [-0.00396183 -0.03078254 -0.01475924  0.01743817 -0.01485418]...
#
# 🔹 Chunk 197:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Beyond impor...
# Embedding: [0.01682965 0.02182928 0.00412926 0.00704349 0.02493729]...
#
# 🔹 Chunk 198:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Send state former. Kit...
# Embedding: [-0.02453241  0.01531393  0.00856734 -0.00763474 -0.0125908 ]...
#
# 🔹 Chunk 199:
# Text: High-speed trains and subways reshaped urban transportation. Parent skin past if race town town. Tur...
# Embedding: [ 0.00839774  0.01213164 -0.00973127  0.0260307  -0.00439703]...
#
# 🔹 Chunk 200:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Recognize she father d...
# Embedding: [ 0.01118999  0.00631066 -0.01644322  0.00915668  0.02423453]...
#
# 🔹 Chunk 201:
# Text: High-speed trains and subways reshaped urban transportation. Catch huge research item. Stage another...
# Embedding: [ 0.02237321  0.00541399  0.04242691  0.01382293 -0.00791846]...
#
# 🔹 Chunk 202:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Teacher the pa...
# Embedding: [-0.03438562  0.01018605  0.03438289 -0.03670686  0.02280067]...
#
# 🔹 Chunk 203:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Position water Democra...
# Embedding: [ 0.00667016  0.01507761  0.0011868  -0.00928756  0.00434236]...
#
# 🔹 Chunk 204:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Product behind...
# Embedding: [-0.00612654 -0.01447864  0.02492496 -0.00877808  0.02446544]...
#
# 🔹 Chunk 205:
# Text: The invention of the wheel revolutionized human movement. Hospital lead will with. Show church such ...
# Embedding: [ 0.0207946   0.00146275  0.00187198  0.02060051 -0.02104557]...
#
# 🔹 Chunk 206:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Bar avoid p...
# Embedding: [-3.44898071e-05 -9.33795888e-03  1.12373941e-02  1.29507920e-02
#   1.62982531e-02]...
#
# 🔹 Chunk 207:
# Text: High-speed trains and subways reshaped urban transportation. Bad citizen break save society. Ground ...
# Embedding: [ 0.0115531  -0.00992848  0.01275841  0.02767243  0.02533061]...
#
# 🔹 Chunk 208:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Today best ...
# Embedding: [ 0.01197778 -0.00509804  0.01491727  0.02225345  0.01482434]...
#
# 🔹 Chunk 209:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01131822  0.03661477 -0.00467915  0.00636921  0.00986797]...
#
# 🔹 Chunk 210:
# Text: The 20th century saw the rise of automobiles and airplanes. Throw election line. Environmental save ...
# Embedding: [-0.00188003  0.04289387  0.02130161  0.04096729 -0.03292816]...
#
# 🔹 Chunk 211:
# Text: The 20th century saw the rise of automobiles and airplanes. Class class at former wife wrong. Yeah s...
# Embedding: [ 0.02921468 -0.01237329  0.03211877  0.0105479  -0.00091254]...
#
# 🔹 Chunk 212:
# Text: High-speed trains and subways reshaped urban transportation. Develop fund building hand gun trip one...
# Embedding: [ 0.00178753  0.00347322  0.02526194  0.02982456 -0.01138863]...
#
# 🔹 Chunk 213:
# Text: The invention of the wheel revolutionized human movement. Movie eight leave for Mr forget involve. I...
# Embedding: [0.01132728 0.00577375 0.02703719 0.00469263 0.00237701]...
#
# 🔹 Chunk 214:
# Text: High-speed trains and subways reshaped urban transportation. Form left land rate. Serve since unit s...
# Embedding: [-0.01676962  0.02008957  0.01793127  0.02018526 -0.02160846]...
#
# 🔹 Chunk 215:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Form intere...
# Embedding: [0.0097199  0.00163393 0.00545071 0.00427673 0.00782569]...
#
# 🔹 Chunk 216:
# Text: The invention of the wheel revolutionized human movement. Him window very daughter. Save home sure c...
# Embedding: [0.00474542 0.03251379 0.00490577 0.01196957 0.00992941]...
#
# 🔹 Chunk 217:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Opportunity ...
# Embedding: [ 0.01968897 -0.01459423  0.00354353  0.01355524 -0.0015717 ]...
#
# 🔹 Chunk 218:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. All leg wes...
# Embedding: [ 0.02322838  0.00589096 -0.00855542  0.03961898  0.03432815]...
#
# 🔹 Chunk 219:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [-0.00436484  0.03759415 -0.00765668  0.01204532 -0.01631005]...
#
# 🔹 Chunk 220:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Dog management free ne...
# Embedding: [ 0.01235418  0.03868798 -0.02429536  0.00022231 -0.02089412]...
#
# 🔹 Chunk 221:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Arrive know contain ec...
# Embedding: [-0.01889595  0.0322505  -0.00648926  0.01392424 -0.0355271 ]...
#
# 🔹 Chunk 222:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Provide vote h...
# Embedding: [-0.03317958  0.01492702  0.02041768 -0.0416453  -0.00399772]...
#
# 🔹 Chunk 223:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.00325199  0.05576436 -0.01141945  0.00720308  0.00402621]...
#
# 🔹 Chunk 224:
# Text: The invention of the wheel revolutionized human movement. Night find listen deal. Food range Republi...
# Embedding: [ 0.00942225  0.02292216  0.00349822  0.01951321 -0.00502015]...
#
# 🔹 Chunk 225:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. F...
# Embedding: [0.01032818 0.0506506  0.03123297 0.01591848 0.00845829]...
#
# 🔹 Chunk 226:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Short projec...
# Embedding: [ 0.03796958  0.00067653  0.02747414  0.00121753 -0.01616624]...
#
# 🔹 Chunk 227:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Close weight...
# Embedding: [-0.01609901  0.00758211  0.0188267   0.03929276  0.01231862]...
#
# 🔹 Chunk 228:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [ 0.01057847  0.03935194 -0.02890453  0.02241538 -0.00358123]...
#
# 🔹 Chunk 229:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. On shoulder be...
# Embedding: [-0.03728641  0.00271934  0.03204712 -0.02146282 -0.00607405]...
#
# 🔹 Chunk 230:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. L...
# Embedding: [ 0.01148908  0.03956662 -0.00106968  0.01324319  0.01757458]...
#
# 🔹 Chunk 231:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. A...
# Embedding: [0.01315059 0.02782086 0.02421151 0.02164874 0.02483227]...
#
# 🔹 Chunk 232:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. N...
# Embedding: [ 0.02564329  0.08343824 -0.03440183  0.01483743 -0.02933528]...
#
# 🔹 Chunk 233:
# Text: In ancient times, transportation was limited to walking and animal domestication. Former bag news es...
# Embedding: [0.03005597 0.02799017 0.02080323 0.01256319 0.01523877]...
#
# 🔹 Chunk 234:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.01540706  0.03894257 -0.00011101  0.01082307  0.00431975]...
#
# 🔹 Chunk 235:
# Text: The invention of the wheel revolutionized human movement. Material happy return everything bill clea...
# Embedding: [-0.0143208   0.00445718  0.01007227  0.00519621 -0.00426705]...
#
# 🔹 Chunk 236:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Reflect shoulder every...
# Embedding: [ 0.01371375  0.0118924  -0.00919121  0.02973779  0.02299085]...
#
# 🔹 Chunk 237:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Same way pr...
# Embedding: [ 0.03867431 -0.0290103   0.00277949  0.00231838  0.03053296]...
#
# 🔹 Chunk 238:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Seek painting ...
# Embedding: [-0.0090278  -0.02267089  0.0481799  -0.04143931  0.0101601 ]...
#
# 🔹 Chunk 239:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.02080004  0.04458342 -0.01252745  0.00643586  0.0258393 ]...
#
# 🔹 Chunk 240:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Lose health worker rea...
# Embedding: [ 0.02826871  0.01549728 -0.0230818   0.0238218  -0.0034982 ]...
#
# 🔹 Chunk 241:
# Text: High-speed trains and subways reshaped urban transportation. Contain suddenly between why result ima...
# Embedding: [-0.0161485  -0.01366101  0.02683404  0.04504867 -0.01800322]...
#
# ...
# Embedding: [ 0.02598987 -0.00365457  0.01227095  0.02317409 -0.00416514]...
#
# 🔹 Chunk 1426:
# Text: In ancient times, transportation was limited to walking and animal domestication. Skill source five ...
# Embedding: [0.04010358 0.05303613 0.02007494 0.02081707 0.00306988]...
#
# 🔹 Chunk 1427:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. O...
# Embedding: [-0.00036567  0.05447702 -0.00328652  0.02552182  0.0066732 ]...
#
# 🔹 Chunk 1428:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Yard majori...
# Embedding: [0.02631899 0.00597325 0.01404709 0.02499273 0.03472865]...
#
# 🔹 Chunk 1429:
# Text: High-speed trains and subways reshaped urban transportation. Never increase perform hundred side rel...
# Embedding: [-0.00514691  0.00268135 -0.00798086  0.02471532  0.00143749]...
#
# 🔹 Chunk 1430:
# Text: The invention of the wheel revolutionized human movement. Phone responsibility about field. Small co...
# Embedding: [ 0.01030044 -0.00944962 -0.01103858  0.0035943   0.00717544]...
#
# 🔹 Chunk 1431:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Approach college claim...
# Embedding: [-0.00737698  0.04633828  0.00920779  0.0107638   0.01776219]...
#
# 🔹 Chunk 1432:
# Text: High-speed trains and subways reshaped urban transportation. Should first usually worry company. If ...
# Embedding: [-0.01842211 -0.00961264  0.02216968  0.02371086 -0.01334378]...
#
# 🔹 Chunk 1433:
# Text: The 20th century saw the rise of automobiles and airplanes. Government citizen away media set tend. ...
# Embedding: [-0.00472516  0.03264594  0.0378565   0.02236406  0.01494143]...
#
# 🔹 Chunk 1434:
# Text: The invention of the wheel revolutionized human movement. Would prove college go amount. Probably sa...
# Embedding: [ 0.01283438 -0.02755246  0.03781188  0.03693219  0.00424722]...
#
# 🔹 Chunk 1435:
# Text: In ancient times, transportation was limited to walking and animal domestication. Result hospital wi...
# Embedding: [ 0.03725531  0.02194258  0.01748338  0.02928744 -0.03558775]...
#
# 🔹 Chunk 1436:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Picture call organizat...
# Embedding: [ 0.00406536  0.02676501  0.00981955  0.00714139 -0.00958036]...
#
# 🔹 Chunk 1437:
# Text: The invention of the wheel revolutionized human movement. Billion goal participant prevent year rece...
# Embedding: [ 0.00068257  0.02758101 -0.01993703  0.02563658 -0.0051657 ]...
#
# 🔹 Chunk 1438:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01024414  0.06057407  0.02970827  0.01420817 -0.0006238 ]...
#
# 🔹 Chunk 1439:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Environmenta...
# Embedding: [0.00599326 0.03084777 0.01592846 0.00351549 0.01885573]...
#
# 🔹 Chunk 1440:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Property green miss on...
# Embedding: [-0.00028927  0.02308223 -0.01746688  0.0227414  -0.00400038]...
#
# 🔹 Chunk 1441:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Respond stay I poor be...
# Embedding: [-0.0060276   0.01380112 -0.01324557  0.00834839 -0.00128733]...
#
# 🔹 Chunk 1442:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. P...
# Embedding: [ 0.00811961  0.03352887  0.02701952  0.00824021 -0.02644978]...
#
# 🔹 Chunk 1443:
# Text: High-speed trains and subways reshaped urban transportation. Theory employee book action lawyer she ...
# Embedding: [ 0.00200116 -0.00846708  0.01309978  0.01026817 -0.02036246]...
#
# 🔹 Chunk 1444:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Together little collec...
# Embedding: [ 0.01203775  0.01812966 -0.01666613  0.01920268 -0.01724535]...
#
# 🔹 Chunk 1445:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Mother break s...
# Embedding: [-0.00951078  0.01329778  0.04156922 -0.01522564 -0.01338077]...
#
# 🔹 Chunk 1446:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Tax determine ...
# Embedding: [-0.02153331  0.00441434  0.01583429  0.00365962  0.00467127]...
#
# 🔹 Chunk 1447:
# Text: The invention of the wheel revolutionized human movement. Possible movement full read give because c...
# Embedding: [ 0.01960735  0.00296849  0.0044962   0.01899218 -0.00147148]...
#
# 🔹 Chunk 1448:
# Text: The 20th century saw the rise of automobiles and airplanes. Quite theory quite shoulder explain. Edu...
# Embedding: [ 0.02983622  0.02656946  0.04617533  0.00337558 -0.00163047]...
#
# 🔹 Chunk 1449:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Boy affect team teach ...
# Embedding: [ 0.02404475  0.02469585  0.01209836  0.02089115 -0.0154057 ]...
#
# 🔹 Chunk 1450:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Push month abi...
# Embedding: [-0.02817407  0.00789873  0.02151793 -0.0558874  -0.00517088]...
#
# 🔹 Chunk 1451:
# Text: The invention of the wheel revolutionized human movement. Else face whose surface around friend miss...
# Embedding: [ 0.02255735  0.0076279   0.02833792  0.00226597 -0.0038821 ]...
#
# 🔹 Chunk 1452:
# Text: In ancient times, transportation was limited to walking and animal domestication. Since matter hear ...
# Embedding: [ 0.02100437 -0.00197739  0.04368927  0.024505    0.02201889]...
#
# 🔹 Chunk 1453:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. A...
# Embedding: [ 0.00816767  0.04212041  0.02564541  0.02898772 -0.00532745]...
#
# 🔹 Chunk 1454:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Me debate foot...
# Embedding: [-0.02574332  0.01532349  0.01408422 -0.05414388 -0.0137919 ]...
#
# 🔹 Chunk 1455:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Decade spring national...
# Embedding: [0.00339241 0.02762788 0.02460537 0.03136258 0.027265  ]...
#
# 🔹 Chunk 1456:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Adult bill ...
# Embedding: [ 0.02552824 -0.01211064  0.0132396   0.02053889  0.01631374]...
#
# 🔹 Chunk 1457:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Shake hand ...
# Embedding: [ 0.03378115 -0.00445152  0.02127353  0.0336579   0.01449844]...
#
# 🔹 Chunk 1458:
# Text: The 20th century saw the rise of automobiles and airplanes. Responsibility culture worry myself. Hop...
# Embedding: [-0.00137347  0.00013367  0.04556338  0.03694458 -0.0302715 ]...
#
# 🔹 Chunk 1459:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Age young b...
# Embedding: [ 0.01975495 -0.01169867  0.00584159 -0.00065714  0.0340033 ]...
#
# 🔹 Chunk 1460:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Statement le...
# Embedding: [ 0.00192413  0.01498248 -0.01417371  0.01517559  0.03737085]...
#
# 🔹 Chunk 1461:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Management ...
# Embedding: [ 0.0250705  -0.00484781 -0.00771481  0.01367829  0.01097435]...
#
# 🔹 Chunk 1462:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Air late do ...
# Embedding: [ 1.49482423e-02 -1.16480170e-02 -1.71754621e-02  1.95617229e-02
#  -1.33858239e-05]...
#
# 🔹 Chunk 1463:
# Text: In ancient times, transportation was limited to walking and animal domestication. Here church thing ...
# Embedding: [ 0.03840951  0.02791932  0.02307715  0.01627032 -0.00173256]...
#
# 🔹 Chunk 1464:
# Text: In ancient times, transportation was limited to walking and animal domestication. Military family sp...
# Embedding: [ 0.02925016  0.01685839  0.03679409  0.00902824 -0.00680192]...
#
# 🔹 Chunk 1465:
# Text: In ancient times, transportation was limited to walking and animal domestication. Recently whose are...
# Embedding: [ 0.02547967  0.02933832  0.04458301  0.00294503 -0.02112413]...
#
# 🔹 Chunk 1466:
# Text: The invention of the wheel revolutionized human movement. Civil entire happen relationship. Describe...
# Embedding: [0.00751877 0.00750012 0.0435655  0.00827758 0.00796756]...
#
# 🔹 Chunk 1467:
# Text: High-speed trains and subways reshaped urban transportation. Into require direction event tonight. V...
# Embedding: [ 0.02431776 -0.00701947 -0.0095875   0.01389248 -0.00782967]...
#
# 🔹 Chunk 1468:
# Text: High-speed trains and subways reshaped urban transportation. Time environment tough think art green ...
# Embedding: [-0.02986571 -0.01938058  0.02589981  0.02089968  0.00246786]...
#
# 🔹 Chunk 1469:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Want recent re...
# Embedding: [ 0.00878208 -0.00057883 -0.011355   -0.02510864 -0.00368737]...
#
# 🔹 Chunk 1470:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Soon four well once. S...
# Embedding: [ 0.00925463  0.01210927 -0.00613829  0.00089853  0.00234713]...
#
# 🔹 Chunk 1471:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. But drive you most. Do...
# Embedding: [0.00854206 0.00823844 0.01223468 0.01666017 0.00670371]...
#
# 🔹 Chunk 1472:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Another rich t...
# Embedding: [-0.02903144  0.00608831  0.02746204 -0.02597898 -0.00046068]...
#
# 🔹 Chunk 1473:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Treatment lo...
# Embedding: [ 0.00860447 -0.01098527 -0.01518534  0.04101809  0.00967999]...
#
# 🔹 Chunk 1474:
# Text: High-speed trains and subways reshaped urban transportation. Its stop spend career. Reach then life ...
# Embedding: [ 0.01784617 -0.00284131  0.02348716  0.01698436 -0.01368511]...
#
# 🔹 Chunk 1475:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Return weigh...
# Embedding: [ 0.00674056 -0.02104054 -0.00204643  0.03397538  0.00327215]...
#
# 🔹 Chunk 1476:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Section skill wrong fo...
# Embedding: [0.03662    0.02493178 0.01954569 0.00514672 0.02709008]...
#
# 🔹 Chunk 1477:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Wonder camera involve ...
# Embedding: [ 0.02149553 -0.00832878  0.00259958  0.01313859  0.02499649]...
#
# 🔹 Chunk 1478:
# Text: In ancient times, transportation was limited to walking and animal domestication. Lose space paper. ...
# Embedding: [ 0.03855628 -0.00506022  0.05023286  0.00795206 -0.02843344]...
#
# 🔹 Chunk 1479:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Across true party here...
# Embedding: [ 0.01375211  0.01651616 -0.00888504  0.01591276  0.0272405 ]...
#
# 🔹 Chunk 1480:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Better focus...
# Embedding: [ 0.00455242 -0.01717699 -0.00543741  0.02437945  0.00088794]...
#
# 🔹 Chunk 1481:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Admit media ...
# Embedding: [ 0.01301945 -0.01624388  0.0136562   0.03027344  0.03263794]...
#
# 🔹 Chunk 1482:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Its already less drop....
# Embedding: [0.02114423 0.04362551 0.02730916 0.01660328 0.01500399]...
#
# 🔹 Chunk 1483:
# Text: High-speed trains and subways reshaped urban transportation. Attack section on reason possible natur...
# Embedding: [ 0.02237337 -0.00847144  0.03923545  0.03168493 -0.0049527 ]...
#
# 🔹 Chunk 1484:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. G...
# Embedding: [ 0.00648408  0.05532336 -0.01189466  0.00899382 -0.00409751]...
#
# 🔹 Chunk 1485:
# Text: The invention of the wheel revolutionized human movement. Crime blood mouth test through role face. ...
# Embedding: [ 0.00532285 -0.01397413  0.02066831  0.00119058  0.01346139]...
#
# 🔹 Chunk 1486:
# Text: In ancient times, transportation was limited to walking and animal domestication. Success return alo...
# Embedding: [ 0.02825404  0.02526499  0.01600973 -0.01756641  0.0055168 ]...
#
# 🔹 Chunk 1487:
# Text: In ancient times, transportation was limited to walking and animal domestication. Among begin tend s...
# Embedding: [ 0.00913653  0.00220882  0.02393499 -0.00805143 -0.00224975]...
#
# 🔹 Chunk 1488:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Style hard gla...
# Embedding: [-0.00402159 -0.01278689  0.02785769 -0.0308263  -0.00744853]...
#
# 🔹 Chunk 1489:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [ 0.01072045  0.06324036  0.02171366  0.02027046 -0.01227068]...
#
# 🔹 Chunk 1490:
# Text: The 20th century saw the rise of automobiles and airplanes. Feeling activity own few service structu...
# Embedding: [ 0.00571219  0.02982277  0.0224927   0.04144077 -0.02853774]...
#
# 🔹 Chunk 1491:
# Text: High-speed trains and subways reshaped urban transportation. World data effort occur. Do top piece l...
# Embedding: [0.02897717 0.00926021 0.03121647 0.03663858 0.00316598]...
#
# 🔹 Chunk 1492:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Crime someth...
# Embedding: [-0.00496141 -0.00995012  0.00078835  0.04615464  0.00663843]...
#
# 🔹 Chunk 1493:
# Text: The 20th century saw the rise of automobiles and airplanes. Program everyone large close far college...
# Embedding: [ 0.0139492   0.0111273   0.03575272 -0.00349774 -0.03490724]...
#
# 🔹 Chunk 1494:
# Text: The 20th century saw the rise of automobiles and airplanes. Firm type cell offer enter yourself even...
# Embedding: [ 0.00031001  0.01138613  0.03121058  0.00048115 -0.0245263 ]...
#
# 🔹 Chunk 1495:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Kid big with...
# Embedding: [0.0103765  0.01209523 0.01364032 0.03260495 0.00969318]...
#
# 🔹 Chunk 1496:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Gun small th...
# Embedding: [ 0.01824815 -0.01255116 -0.01184268  0.01275441  0.00969352]...
#
# 🔹 Chunk 1497:
# Text: In ancient times, transportation was limited to walking and animal domestication. Million already bi...
# Embedding: [0.03264011 0.04416882 0.01762258 0.02547825 0.0043913 ]...
#
# 🔹 Chunk 1498:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. T...
# Embedding: [ 0.00273238  0.01821041 -0.0052631   0.03125836 -0.01114648]...
#
# 🔹 Chunk 1499:
# Text: The invention of the wheel revolutionized human movement. Important mean almost because. Clear famil...
# Embedding: [0.00906724 0.02736569 0.01009212 0.05208743 0.01013868]...
#
# 🔹 Chunk 1500:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Already the...
# Embedding: [ 0.02147646 -0.0105885   0.00532412  0.02095545  0.03482546]...
#
# 🔹 Chunk 1501:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Beautiful year key rel...
# Embedding: [-0.01020183 -0.00535212 -0.00328797  0.01829775 -0.0134814 ]...
#
# 🔹 Chunk 1502:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Education federal afte...
# Embedding: [ 0.00223447  0.01014669  0.00137032 -0.01312007  0.00644355]...
#
# 🔹 Chunk 1503:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Need contain step hers...
# Embedding: [-0.02231126  0.00214165 -0.0185562  -0.00857553  0.00879979]...
#
# 🔹 Chunk 1504:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Number both...
# Embedding: [ 0.04433665 -0.01722114 -0.01294652  0.00744267  0.0242571 ]...

# %%
# Step 6: Store in Chroma DB
persist_directory = "chroma_db"

# Step 7: Create Chroma vector store and persist
try:
    vectorstore = Chroma.from_documents(
        documents=documents,
        embedding=embedding_model,
        persist_directory=persist_directory
    )
    vectorstore.persist()
    print("✅ Embeddings stored successfully in Chroma DB.")
except Exception as e:
    print(f"Error storing embeddings: {e}")
    import sys
    sys.exit(1)

# Step 8: Explicitly request embeddings, metadata, and documents
results = vectorstore.get(include=["embeddings", "metadatas", "documents"])
print(f"Number of embeddings: {len(results['embeddings'])}")

# Step 9: Print each chunk and its embedding
for i, (embedding, metadata, document) in enumerate(zip(results["embeddings"], results["metadatas"], results["documents"])):
    print(f"\n🔹 Chunk {i+1}:")
    print(f"Text: {document[:100]}...")  # First 100 characters
    print(f"Embedding: {embedding[:5]}...")  # First 5 dimensions
# Out:
# ✅ Embeddings stored successfully in Chroma DB.
# Number of embeddings: 1880
#
# 🔹 Chunk 1:
# Text: The invention of the wheel revolutionized human movement. American whole magazine truth stop whose. ...
# Embedding: [ 0.00135405 -0.00638477  0.02167933  0.0439051   0.01640437]...
#
# 🔹 Chunk 2:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Kind miss ar...
# Embedding: [ 0.01892734 -0.01751047  0.02744835  0.00064038  0.00643887]...
#
# 🔹 Chunk 3:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Attorney quickly candi...
# Embedding: [ 0.01401016  0.00997913 -0.00108978  0.02315456  0.00525275]...
#
# 🔹 Chunk 4:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Decision so...
# Embedding: [ 0.02067159  0.00056219 -0.00738473  0.00110476  0.00992023]...
#
# 🔹 Chunk 5:
# Text: High-speed trains and subways reshaped urban transportation. Exactly drive well good explain grow wa...
# Embedding: [ 0.01034095  0.00454821 -0.00739463  0.00665863 -0.01190622]...
#
# 🔹 Chunk 6:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Physical again...
# Embedding: [-0.01013022  0.0152913   0.03000627 -0.02689739  0.00873518]...
#
# 🔹 Chunk 7:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [0.02710649 0.04063169 0.00030573 0.01783803 0.01118263]...
#
# 🔹 Chunk 8:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Institution ...
# Embedding: [ 0.00859615 -0.01788422  0.00863766  0.03537644 -0.01225005]...
#
# 🔹 Chunk 9:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. P...
# Embedding: [ 0.01032474  0.05951204 -0.02530056  0.01073758  0.00561421]...
#
# 🔹 Chunk 10:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Technology song than l...
# Embedding: [ 0.01545037 -0.00312915  0.00385527  0.01402903  0.01529741]...
#
# 🔹 Chunk 11:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [ 0.03957947 -0.00212144  0.0008352  -0.00504253  0.01534999]...
#
# 🔹 Chunk 12:
# Text: High-speed trains and subways reshaped urban transportation. Crime situation since book art red. Pla...
# Embedding: [0.01734441 0.00097032 0.02220173 0.02951219 0.02361661]...
#
# 🔹 Chunk 13:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Medical watc...
# Embedding: [-0.01656478 -0.00311965  0.0249093  -0.01780729  0.01421725]...
#
# 🔹 Chunk 14:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Player contain...
# Embedding: [-0.03287061  0.00854697  0.03114654 -0.04174445  0.00451194]...
#
# 🔹 Chunk 15:
# Text: In ancient times, transportation was limited to walking and animal domestication. Fear great easy pl...
# Embedding: [ 0.04154009  0.0069941   0.01658453 -0.01609668  0.01850813]...
#
# 🔹 Chunk 16:
# Text: In ancient times, transportation was limited to walking and animal domestication. Set discussion sev...
# Embedding: [0.06350676 0.0264297  0.01513552 0.00562692 0.00901803]...
#
# 🔹 Chunk 17:
# Text: The 20th century saw the rise of automobiles and airplanes. Scientist tough everything kind nothing ...
# Embedding: [-0.00665252  0.00825622  0.04259735  0.00524029  0.00480471]...
#
# 🔹 Chunk 18:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Guess break ...
# Embedding: [ 0.01665775  0.02652714 -0.01985754  0.03266746 -0.00232584]...
#
# 🔹 Chunk 19:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Report town...
# Embedding: [ 0.0330526   0.00115437 -0.01852984  0.00819488  0.00500499]...
#
# 🔹 Chunk 20:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. About pressu...
# Embedding: [ 0.04320978  0.02262346  0.03488009 -0.00216891 -0.00566406]...
#
# 🔹 Chunk 21:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Where economic detail....
# Embedding: [ 0.02037243  0.00699025 -0.03065869  0.0076532  -0.0196282 ]...
#
# 🔹 Chunk 22:
# Text: The invention of the wheel revolutionized human movement. Case administration measure happen. Speech...
# Embedding: [ 0.01087756 -0.00297447  0.01151642  0.01282349  0.01043388]...
#
# 🔹 Chunk 23:
# Text: The 20th century saw the rise of automobiles and airplanes. Region bad case I course first. Himself ...
# Embedding: [ 0.00396031  0.01124496  0.03331418  0.00762268 -0.00708194]...
#
# 🔹 Chunk 24:
# Text: In ancient times, transportation was limited to walking and animal domestication. North but west. Ab...
# Embedding: [ 0.02983807  0.00762941  0.01412852  0.00320008 -0.01910503]...
#
# 🔹 Chunk 25:
# Text: The invention of the wheel revolutionized human movement. Several might history strong economy. Not ...
# Embedding: [ 0.02291865  0.00449816  0.0082826   0.01244083 -0.00946319]...
#
# 🔹 Chunk 26:
# Text: High-speed trains and subways reshaped urban transportation. Find add sing standard exactly. Mrs nev...
# Embedding: [-0.00684631 -0.01721914  0.03977426  0.03675831 -0.01488476]...
#
# 🔹 Chunk 27:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Action economy...
# Embedding: [-0.01504395  0.00032424  0.03692569 -0.02572586  0.00387482]...
#
# 🔹 Chunk 28:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Wear general...
# Embedding: [0.00592012 0.00264144 0.00953296 0.04433871 0.00541789]...
#
# 🔹 Chunk 29:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Later street mention w...
# Embedding: [ 0.03123564  0.01035354 -0.0121395   0.02183039  0.0051933 ]...
#
# 🔹 Chunk 30:
# Text: The 20th century saw the rise of automobiles and airplanes. Where a front war receive. Company TV po...
# Embedding: [ 0.01856102  0.01612486  0.02559228  0.02878076 -0.01715788]...
#
# 🔹 Chunk 31:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Head against particula...
# Embedding: [0.01741394 0.0339983  0.02390708 0.02903032 0.01476544]...
#
# 🔹 Chunk 32:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Risk catch check clear...
# Embedding: [ 0.00059894  0.0061745  -0.02887046  0.01331419 -0.01610162]...
#
# 🔹 Chunk 33:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Blood single r...
# Embedding: [-0.01050555  0.01579139  0.04418492  0.01602879 -0.0134087 ]...
#
# 🔹 Chunk 34:
# Text: The invention of the wheel revolutionized human movement. Popular if do them. Lose big strategy. Nea...
# Embedding: [ 0.01092814  0.009287   -0.00965585  0.01094413 -0.00831182]...
#
# 🔹 Chunk 35:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Great weste...
# Embedding: [ 0.04641478 -0.01516347  0.00380911 -0.00591277  0.01114186]...
#
# 🔹 Chunk 36:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. F...
# Embedding: [0.03135369 0.05454789 0.00286939 0.05257638 0.00818571]...
#
# 🔹 Chunk 37:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Unit dinner...
# Embedding: [ 0.01749396 -0.02427198 -0.01043934  0.02902098 -0.00031827]...
#
# 🔹 Chunk 38:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Can effort bad...
# Embedding: [-0.03649027  0.00620465  0.02696783 -0.03179351 -0.01017576]...
#
# 🔹 Chunk 39:
# Text: In ancient times, transportation was limited to walking and animal domestication. Could foreign mind...
# Embedding: [ 0.01986704  0.00403129  0.01939112 -0.0071887   0.01497106]...
#
# 🔹 Chunk 40:
# Text: In ancient times, transportation was limited to walking and animal domestication. Hospital wrong fis...
# Embedding: [ 0.04452832 -0.00435592  0.0241381  -0.01474819 -0.00698089]...
#
# 🔹 Chunk 41:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Station enough become ...
# Embedding: [ 0.03045688  0.00502043 -0.00155125  0.03349259  0.0316801 ]...
#
# 🔹 Chunk 42:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Yet really which human...
# Embedding: [ 0.03032649  0.03398637 -0.01488264  0.01179942 -0.01490438]...
#
# 🔹 Chunk 43:
# Text: High-speed trains and subways reshaped urban transportation. Company drop join recognize all structu...
# Embedding: [ 0.01796937 -0.01521986  0.03202607  0.03622484 -0.00942456]...
#
# 🔹 Chunk 44:
# Text: In ancient times, transportation was limited to walking and animal domestication. Air ball better co...
# Embedding: [0.04101714 0.02980621 0.01105216 0.01256565 0.00918656]...
#
# 🔹 Chunk 45:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Late every include gen...
# Embedding: [ 0.01564493  0.01929698 -0.01312992  0.01609978  0.00129967]...
#
# 🔹 Chunk 46:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Smile creat...
# Embedding: [0.03281455 0.00541195 0.002243   0.02567124 0.03139791]...
#
# 🔹 Chunk 47:
# Text: The invention of the wheel revolutionized human movement. Evening scene that himself floor somebody ...
# Embedding: [ 0.01168964  0.00031366  0.01385987  0.0179572  -0.00817137]...
#
# 🔹 Chunk 48:
# Text: The 20th century saw the rise of automobiles and airplanes. Part instead city type short rather. Onc...
# Embedding: [-0.01214391  0.01810784  0.06787446 -0.00409586 -0.02418566]...
#
# 🔹 Chunk 49:
# Text: In ancient times, transportation was limited to walking and animal domestication. See different deci...
# Embedding: [0.02422148 0.00322741 0.03227796 0.00266658 0.00102591]...
#
# 🔹 Chunk 50:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Voice boy forward scie...
# Embedding: [ 0.02574064  0.02734374 -0.00448741  0.00998215  0.0203305 ]...
#
# 🔹 Chunk 51:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Level gener...
# Embedding: [ 0.01533446  0.00495567  0.01462035 -0.00049756  0.01933352]...
#
# 🔹 Chunk 52:
# Text: High-speed trains and subways reshaped urban transportation. Mention hot happy far. Effort drop onto...
# Embedding: [-0.0046944   0.01405798  0.01769429  0.02555199 -0.01840921]...
#
# 🔹 Chunk 53:
# Text: The 20th century saw the rise of automobiles and airplanes. Tell boy arrive. Several past next final...
# Embedding: [ 0.01584681  0.00869239  0.03725192  0.0097416  -0.00043126]...
#
# 🔹 Chunk 54:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Goal probab...
# Embedding: [ 0.03589366 -0.01898164  0.00630865  0.00932456  0.00788249]...
#
# 🔹 Chunk 55:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Box operatio...
# Embedding: [ 0.03937767  0.02336198  0.04468286  0.03722329 -0.02856412]...
#
# 🔹 Chunk 56:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Over ten tree pull lik...
# Embedding: [ 0.0252867   0.01590184 -0.01405719  0.03743102 -0.00209513]...
#
# 🔹 Chunk 57:
# Text: High-speed trains and subways reshaped urban transportation. House central baby picture choice could...
# Embedding: [ 0.00640651  0.00781298  0.02451759  0.02000117 -0.01300726]...
#
# 🔹 Chunk 58:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Civil market value dur...
# Embedding: [0.01211476 0.01627905 0.0071454  0.0086737  0.00395645]...
#
# 🔹 Chunk 59:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Member sign life succe...
# Embedding: [-0.00303409  0.01556161 -0.01479806  0.03418414  0.02503243]...
#
# 🔹 Chunk 60:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Administrati...
# Embedding: [ 0.02133231  0.01017572  0.01670065  0.0280281  -0.00319302]...
#
# 🔹 Chunk 61:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Relate number night ad...
# Embedding: [3.17917913e-02 1.45056387e-02 7.47618833e-05 3.15341428e-02
#  7.81726278e-03]...
#
# 🔹 Chunk 62:
# Text: The 20th century saw the rise of automobiles and airplanes. Activity note attention yeah process res...
# Embedding: [-0.00284975  0.01669067  0.03439831  0.02109394 -0.01773831]...
#
# 🔹 Chunk 63:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Physical play ...
# Embedding: [-0.02300419  0.00780155  0.03686797 -0.02617365  0.00354631]...
#
# 🔹 Chunk 64:
# Text: High-speed trains and subways reshaped urban transportation. Face key when also. Citizen to produce ...
# Embedding: [ 0.02103886 -0.0011416   0.01458336  0.02421782 -0.01204676]...
#
# 🔹 Chunk 65:
# Text: High-speed trains and subways reshaped urban transportation. When room network behind social her he....
# Embedding: [-0.00442829  0.00795173  0.01043982  0.04289033  0.00672974]...
#
# 🔹 Chunk 66:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. W...
# Embedding: [0.00334015 0.04404609 0.01266618 0.00190478 0.00194587]...
#
# 🔹 Chunk 67:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Plant color current no...
# Embedding: [-0.0031564  -0.00159657 -0.01183798  0.02290569  0.00789284]...
#
# 🔹 Chunk 68:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Share address than cou...
# Embedding: [ 0.00650673  0.00121898  0.00100273  0.01217515 -0.01057126]...
#
# 🔹 Chunk 69:
# Text: The 20th century saw the rise of automobiles and airplanes. Beat sometimes Republican agent manage s...
# Embedding: [0.01646647 0.01123776 0.02514665 0.0188732  0.0198627 ]...
#
# 🔹 Chunk 70:
# Text: The 20th century saw the rise of automobiles and airplanes. Fill can cause as. Create agree likely o...
# Embedding: [-0.01383472  0.0428497   0.06304392 -0.01313708 -0.01592597]...
#
# 🔹 Chunk 71:
# Text: High-speed trains and subways reshaped urban transportation. Speak let guy son. Gas class wish relat...
# Embedding: [ 0.00060902 -0.00290987  0.01046217  0.01832111 -0.00325969]...
#
# 🔹 Chunk 72:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Place strong parent be...
# Embedding: [-0.00967644 -0.00141954  0.00555993 -0.00439511  0.01084874]...
#
# 🔹 Chunk 73:
# Text: The 20th century saw the rise of automobiles and airplanes. Operation point loss mean production est...
# Embedding: [-0.00553122  0.0129007   0.01511583  0.03469853 -0.02286858]...
#
# 🔹 Chunk 74:
# Text: In ancient times, transportation was limited to walking and animal domestication. Rest others develo...
# Embedding: [ 0.03493589  0.03697083  0.00337668 -0.00910505 -0.00662269]...
#
# 🔹 Chunk 75:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. U...
# Embedding: [ 0.00181716  0.04429856  0.00214767 -0.0194149   0.00754326]...
#
# 🔹 Chunk 76:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. C...
# Embedding: [ 0.0244045   0.05192607 -0.00927821  0.01797803  0.01004338]...
#
# 🔹 Chunk 77:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Social per civil. Same...
# Embedding: [0.01755009 0.01411434 0.00926731 0.04411989 0.0190275 ]...
#
# 🔹 Chunk 78:
# Text: In ancient times, transportation was limited to walking and animal domestication. Kitchen mind wife ...
# Embedding: [ 0.04705589  0.0009751   0.01132399  0.00247212 -0.02447801]...
#
# 🔹 Chunk 79:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Economic att...
# Embedding: [ 0.00217993  0.0182313  -0.011056    0.0041718   0.0098821 ]...
#
# 🔹 Chunk 80:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. It start no...
# Embedding: [ 0.01679288 -0.0061792  -0.01496638  0.0144983   0.00656139]...
#
# 🔹 Chunk 81:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Other quest...
# Embedding: [ 0.01759372 -0.01935459  0.02294608  0.0401215   0.01764129]...
#
# 🔹 Chunk 82:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Book they fiel...
# Embedding: [-0.01093816  0.02375851  0.03238443 -0.02493139  0.00936203]...
#
# 🔹 Chunk 83:
# Text: High-speed trains and subways reshaped urban transportation. Feel beat why matter instead need confe...
# Embedding: [ 0.02364915 -0.00214977  0.00611251  0.05021822 -0.01599673]...
#
# 🔹 Chunk 84:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Not identify score. Ha...
# Embedding: [ 0.01602666  0.0052108  -0.01988497  0.0159088  -0.00186412]...
#
# 🔹 Chunk 85:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Decade plant identify ...
# Embedding: [ 0.01152404 -0.00146876 -0.00367877  0.0267028   0.00978158]...
#
# 🔹 Chunk 86:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Prevent new...
# Embedding: [ 0.01145666  0.0116814  -0.00583879  0.00267936  0.02493654]...
#
# 🔹 Chunk 87:
# Text: The 20th century saw the rise of automobiles and airplanes. Media successful anyone candidate defens...
# Embedding: [-0.00068188  0.02257611  0.03807098  0.03779644  0.00408962]...
#
# 🔹 Chunk 88:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.00810609  0.03390926 -0.01524146  0.01682171  0.01192944]...
#
# 🔹 Chunk 89:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Space store ...
# Embedding: [0.00122482 0.00812037 0.00160893 0.05047002 0.01416797]...
#
# 🔹 Chunk 90:
# Text: In ancient times, transportation was limited to walking and animal domestication. Soon four once ent...
# Embedding: [ 0.01353897  0.02971156  0.03801423 -0.03713699  0.00973546]...
#
# 🔹 Chunk 91:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Half importa...
# Embedding: [-0.00718313 -0.0101809  -0.00325261  0.00949943 -0.00630479]...
#
# 🔹 Chunk 92:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Embedding: [ 0.01764813 -0.00877199  0.00286054  0.01826868  0.02234158]...
#
# 🔹 Chunk 93:
# Text: High-speed trains and subways reshaped urban transportation. Current by write north product well sch...
# Embedding: [ 0.00286829 -0.03099594  0.01867948  0.01721779 -0.01148152]...
#
# 🔹 Chunk 94:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Call various...
# Embedding: [0.03335737 0.02169948 0.00957457 0.02269132 0.01241124]...
#
# 🔹 Chunk 95:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Hit half agreement spe...
# Embedding: [0.01887314 0.00705545 0.00761925 0.01218661 0.02407484]...
#
# 🔹 Chunk 96:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Deep anythi...
# Embedding: [ 0.01250027 -0.00937822 -0.00013767  0.00285409  0.01640946]...
#
# 🔹 Chunk 97:
# Text: The 20th century saw the rise of automobiles and airplanes. Identify involve hospital capital others...
# Embedding: [0.01952354 0.00989266 0.03362218 0.01203185 0.02404428]...
#
# 🔹 Chunk 98:
# Text: High-speed trains and subways reshaped urban transportation. Ready the theory moment better of music...
# Embedding: [-0.02337343 -0.00352904  0.0388845  -0.02054176 -0.01671087]...
#
# 🔹 Chunk 99:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Others sort fo...
# Embedding: [-0.00805014 -0.00958581  0.02795397  0.00239695  0.0001035 ]...
#
# 🔹 Chunk 100:
# Text: In ancient times, transportation was limited to walking and animal domestication. Hope current page....
# Embedding: [ 0.04619366  0.03939649  0.04582964 -0.00906708 -0.01791854]...
#
# 🔹 Chunk 101:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. G...
# Embedding: [-0.0023846   0.01927193  0.00322986 -0.00306807 -0.01201701]...
#
# 🔹 Chunk 102:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [-0.00142482  0.01874286 -0.00808824  0.02043053  0.03029315]...
#
# 🔹 Chunk 103:
# Text: The invention of the wheel revolutionized human movement. When general everything center wind note n...
# Embedding: [-0.02339034  0.00764162  0.02444959 -0.04096855  0.01187676]...
#
# 🔹 Chunk 104:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Forget crime r...
# Embedding: [-0.01210557  0.00814977  0.0326561  -0.01725802 -0.00103051]...
#
# 🔹 Chunk 105:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Become lead...
# Embedding: [ 0.00496482 -0.03395941 -0.00566701 -0.00816338  0.02649047]...
#
# 🔹 Chunk 106:
# Text: The 20th century saw the rise of automobiles and airplanes. Prevent manage line. Range happen look a...
# Embedding: [-0.02421213  0.01352752  0.04033504 -0.0003384  -0.01785848]...
#
# 🔹 Chunk 107:
# Text: The 20th century saw the rise of automobiles and airplanes. Traditional probably article last forwar...
# Embedding: [0.00827118 0.04324884 0.02095649 0.01198842 0.00182626]...
#
# 🔹 Chunk 108:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Door admit visit again...
# Embedding: [ 0.02626335  0.03419691 -0.01556152  0.02630091 -0.00512115]...
#
# 🔹 Chunk 109:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Game which sto...
# Embedding: [-0.00438841  0.00065215  0.04251147 -0.00647971  0.00869688]...
#
# 🔹 Chunk 110:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Quality pro...
# Embedding: [ 0.03175918 -0.00087328  0.01234225  0.02782521  0.03711044]...
#
# 🔹 Chunk 111:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Account reason sure ac...
# Embedding: [ 0.00223445  0.00634137 -0.0239439   0.00807533  0.01322997]...
#
# 🔹 Chunk 112:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Concern wor...
# Embedding: [ 0.01086435 -0.02242698 -0.00382877  0.01999187  0.00736547]...
#
# 🔹 Chunk 113:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Magazine paper age phy...
# Embedding: [0.02039408 0.00242891 0.00867894 0.01640816 0.01326888]...
#
# 🔹 Chunk 114:
# Text: In ancient times, transportation was limited to walking and animal domestication. Tonight woman driv...
# Embedding: [0.0191534  0.06648143 0.01416508 0.00055654 0.010098  ]...
#
# 🔹 Chunk 115:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. M...
# Embedding: [0.06100725 0.05338929 0.00804091 0.01944676 0.00399611]...
#
# 🔹 Chunk 116:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Could number for as hi...
# Embedding: [ 0.00212298  0.01113734 -0.00769884 -0.00806746 -0.00543861]...
#
# 🔹 Chunk 117:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.01432353  0.05529489  0.00684418 -0.0016096   0.00208176]...
#
# 🔹 Chunk 118:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Team front mother poss...
# Embedding: [ 0.02022926  0.02083773 -0.0332002   0.01208635 -0.00198642]...
#
# 🔹 Chunk 119:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Dinner both in sea res...
# Embedding: [ 0.00782579  0.02250655 -0.01646447  0.00049735 -0.00080942]...
#
# 🔹 Chunk 120:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Country tow...
# Embedding: [ 0.03626595 -0.01095205  0.01050314  0.01379833  0.00214509]...
#
# 🔹 Chunk 121:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Social examp...
# Embedding: [-0.001962    0.00600956 -0.00628864  0.02023999  0.02453626]...
#
# 🔹 Chunk 122:
# Text: The 20th century saw the rise of automobiles and airplanes. Crime thank mean edge among direction. S...
# Embedding: [-0.00164933  0.03593979  0.0336038   0.0415532  -0.03139539]...
#
# 🔹 Chunk 123:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Education answer blood...
# Embedding: [ 0.01648489  0.02022207 -0.00808012  0.01844695  0.02744084]...
#
# 🔹 Chunk 124:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Size worry ...
# Embedding: [ 0.05044487 -0.00327398  0.01260192  0.02682239  0.02855976]...
#
# 🔹 Chunk 125:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Talk ago green...
# Embedding: [-0.05078843  0.01370989  0.03616673 -0.02998482 -0.01262825]...
#
# 🔹 Chunk 126:
# Text: In ancient times, transportation was limited to walking and animal domestication. Practice yes kind ...
# Embedding: [ 0.02804125  0.03759567  0.03110993  0.00539453 -0.01231349]...
#
# 🔹 Chunk 127:
# Text: High-speed trains and subways reshaped urban transportation. Stop law you well else candidate relati...
# Embedding: [ 0.01656347  0.02051693  0.03546134  0.01334403 -0.02410349]...
#
# 🔹 Chunk 128:
# Text: High-speed trains and subways reshaped urban transportation. Home yard give film question record. La...
# Embedding: [ 0.00404559 -0.01715502  0.03699593  0.02190899  0.00756236]...
#
# 🔹 Chunk 129:
# Text: The 20th century saw the rise of automobiles and airplanes. Class game may television sense. Animal ...
# Embedding: [0.02305428 0.02141379 0.03867211 0.02266415 0.00733686]...
#
# 🔹 Chunk 130:
# Text: In ancient times, transportation was limited to walking and animal domestication. Behind section rat...
# Embedding: [ 5.51789664e-02  4.13591834e-03  4.59835120e-02  3.57682948e-05
#  -1.95224304e-02]...
#
# 🔹 Chunk 131:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. What discuss campaign ...
# Embedding: [0.02184725 0.05019384 0.01740206 0.01699844 0.01725678]...
#
# 🔹 Chunk 132:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Health good commercial...
# Embedding: [ 0.00491794  0.00979169 -0.01028273  0.0189352  -0.00724908]...
#
# 🔹 Chunk 133:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Produce decision dinne...
# Embedding: [ 0.0236522   0.01676001 -0.00012713  0.03796623  0.02113018]...
#
# 🔹 Chunk 134:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. That thing owner where...
# Embedding: [ 0.0092324  -0.01875326 -0.01995671  0.01523625  0.02873464]...
#
# 🔹 Chunk 135:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Drug probabl...
# Embedding: [ 0.01048125 -0.01311716  0.0106995   0.0084283   0.01190628]...
#
# 🔹 Chunk 136:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Pressure ball financia...
# Embedding: [ 0.01038751  0.00982841 -0.00869197  0.00193772 -0.0055791 ]...
#
# 🔹 Chunk 137:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. We later arrive child....
# Embedding: [-0.00156517  0.00881165 -0.01066471 -0.0153444   0.01402547]...
#
# 🔹 Chunk 138:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. K...
# Embedding: [0.00700701 0.04079218 0.00166535 0.01631842 0.00418497]...
#
# 🔹 Chunk 139:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Boy while to...
# Embedding: [0.00587152 0.03450105 0.00502999 0.00278489 0.00659922]...
#
# 🔹 Chunk 140:
# Text: The invention of the wheel revolutionized human movement. Light film cell effort gun. Instead specif...
# Embedding: [ 0.02573465 -0.00155675  0.00296704  0.00578587  0.00752609]...
#
# 🔹 Chunk 141:
# Text: In ancient times, transportation was limited to walking and animal domestication. Green together int...
# Embedding: [ 0.05694081  0.02285983  0.01761263 -0.00251171 -0.02664263]...
#
# 🔹 Chunk 142:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Thousand season progra...
# Embedding: [ 0.00737643  0.01327211 -0.00976155  0.02814642  0.03809311]...
#
# 🔹 Chunk 143:
# Text: The 20th century saw the rise of automobiles and airplanes. Red however draw ten reflect. Price trou...
# Embedding: [ 0.0091231   0.03323423  0.00877705 -0.00829168  0.00430265]...
#
# 🔹 Chunk 144:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Him local sing...
# Embedding: [-0.00671378 -0.00322587  0.01188125 -0.02522677  0.0158673 ]...
#
# 🔹 Chunk 145:
# Text: The invention of the wheel revolutionized human movement. Population process future else establish p...
# Embedding: [-0.00230328  0.00920659  0.02479174  0.0037978   0.00029428]...
#
# 🔹 Chunk 146:
# Text: The invention of the wheel revolutionized human movement. Just within threat. Physical who establish...
# Embedding: [ 0.04753664  0.02156864 -0.00961098  0.01609055 -0.04208924]...
#
# 🔹 Chunk 147:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [-0.00071647  0.06723276  0.00384819  0.0259508   0.00221841]...
#
# 🔹 Chunk 148:
# Text: In ancient times, transportation was limited to walking and animal domestication. Professional ident...
# Embedding: [ 0.02089796  0.04496919  0.01589135  0.00558983 -0.00033414]...
#
# 🔹 Chunk 149:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Try wait side part wes...
# Embedding: [ 0.00278858  0.01108915  0.01884811 -0.02566858  0.00935431]...
#
# 🔹 Chunk 150:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Plan your pa...
# Embedding: [ 0.00753642 -0.00709374 -0.01229759  0.0398423   0.027069  ]...
#
# 🔹 Chunk 151:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Cut product...
# Embedding: [ 0.01537674 -0.02689081 -0.0075088   0.01668818  0.01930979]...
#
# 🔹 Chunk 152:
# Text: High-speed trains and subways reshaped urban transportation. Decision assume successful. Marriage pe...
# Embedding: [ 0.01600401 -0.00742408  0.01147352  0.00231384 -0.0216101 ]...
#
# 🔹 Chunk 153:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Amount natio...
# Embedding: [0.03598719 0.0209609  0.04941085 0.02726529 0.00571616]...
#
# 🔹 Chunk 154:
# Text: The invention of the wheel revolutionized human movement. Image him soldier suddenly myself imagine ...
# Embedding: [-0.00750209  0.02444375  0.00536434 -0.00253377 -0.01124981]...
#
# 🔹 Chunk 155:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Threat hous...
# Embedding: [0.01827643 0.01037451 0.00105235 0.01933244 0.01729224]...
#
# 🔹 Chunk 156:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Concern toward fast sp...
# Embedding: [1.84104101e-05 1.64721403e-02 3.04433797e-03 1.89770944e-02
#  7.22474186e-03]...
#
# 🔹 Chunk 157:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Heart that American li...
# Embedding: [ 0.02851938  0.00513923 -0.02044771  0.04839508  0.01963439]...
#
# 🔹 Chunk 158:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. American need outside ...
# Embedding: [-0.00069169  0.02041925 -0.01496213  0.00955238  0.00859411]...
#
# 🔹 Chunk 159:
# Text: High-speed trains and subways reshaped urban transportation. Firm phone conference someone relate. P...
# Embedding: [ 0.01599281 -0.00351692  0.00206683  0.03583451 -0.01223455]...
#
# 🔹 Chunk 160:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Marriage gro...
# Embedding: [-0.00659858  0.00649627  0.00068199  0.00834672  0.01047021]...
#
# 🔹 Chunk 161:
# Text: The 20th century saw the rise of automobiles and airplanes. Where Mrs above husband. Southern size r...
# Embedding: [ 0.00569319  0.03745851  0.05092549  0.00527619 -0.01437058]...
#
# 🔹 Chunk 162:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. C...
# Embedding: [ 0.01938909  0.03621551 -0.0175213  -0.00184171  0.00394057]...
#
# 🔹 Chunk 163:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Especially writer air ...
# Embedding: [ 0.00964246  0.0097872  -0.007796    0.01453749  0.0327025 ]...
#
# 🔹 Chunk 164:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01378673  0.03362676 -0.00376769  0.01440501 -0.00698317]...
#
# 🔹 Chunk 165:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Will your appr...
# Embedding: [ 0.0015249   0.02341338  0.02439686 -0.01068136 -0.00498998]...
#
# 🔹 Chunk 166:
# Text: High-speed trains and subways reshaped urban transportation. Effect message west take black impact h...
# Embedding: [-0.02716265 -0.01200727  0.03540753  0.04139767 -0.01270721]...
#
# 🔹 Chunk 167:
# Text: The 20th century saw the rise of automobiles and airplanes. Evidence something really manage read th...
# Embedding: [ 0.00587068  0.01826657  0.04395685  0.01301811 -0.01260765]...
#
# 🔹 Chunk 168:
# Text: High-speed trains and subways reshaped urban transportation. Quickly foot star. Movie present people...
# Embedding: [ 0.01223859 -0.00159237  0.00389048  0.01152543 -0.01064716]...
#
# 🔹 Chunk 169:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Company many agency sh...
# Embedding: [-1.81838677e-05 -8.80145375e-03  1.06223812e-02  2.57002115e-02
#   2.59329248e-02]...
#
# 🔹 Chunk 170:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Least sort rise actual...
# Embedding: [0.01460422 0.00887088 0.01470595 0.00165328 0.03011917]...
#
# 🔹 Chunk 171:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Bill both after analys...
# Embedding: [-0.01461958  0.02279857 -0.01185588  0.00426819 -0.00955606]...
#
# 🔹 Chunk 172:
# Text: The invention of the wheel revolutionized human movement. Increase concern pressure. Treat push firs...
# Embedding: [ 0.02986271  0.01445072  0.01910432  0.02529137 -0.01774891]...
#
# 🔹 Chunk 173:
# Text: The invention of the wheel revolutionized human movement. Stock story glass employee listen require ...
# Embedding: [-0.00405313 -0.00291416 -0.01298771  0.01830394 -0.010227  ]...
#
# 🔹 Chunk 174:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Nothing course claim u...
# Embedding: [ 0.02760874  0.04007047  0.00576227  0.00471083 -0.00492599]...
#
# 🔹 Chunk 175:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Drop use dream...
# Embedding: [-0.02578749  0.00323587  0.02297177 -0.03377908  0.00352771]...
#
# 🔹 Chunk 176:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Later image...
# Embedding: [ 0.02100461 -0.00669769  0.01428407 -0.01098064  0.01822886]...
#
# 🔹 Chunk 177:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [0.00208138 0.06380757 0.02403099 0.01188998 0.00720604]...
#
# 🔹 Chunk 178:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Not nor leg sister oil...
# Embedding: [-0.00384633  0.01118418 -0.01522246  0.0155482  -0.01398379]...
#
# 🔹 Chunk 179:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Art director herself t...
# Embedding: [-0.00937301 -0.00437298 -0.00590195  0.00423368  0.01180463]...
#
# 🔹 Chunk 180:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Mean approac...
# Embedding: [ 0.00594353  0.02044763 -0.03765455 -0.01220966  0.00073344]...
#
# 🔹 Chunk 181:
# Text: The 20th century saw the rise of automobiles and airplanes. Language indeed bring account candidate....
# Embedding: [0.01607317 0.037135   0.02855582 0.02085264 0.00508406]...
#
# 🔹 Chunk 182:
# Text: High-speed trains and subways reshaped urban transportation. Student plan among relate decade. Succe...
# Embedding: [ 0.0077704  -0.03766566  0.00386248  0.03635035 -0.01294966]...
#
# 🔹 Chunk 183:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Institution agency whi...
# Embedding: [0.00425287 0.01165391 0.00807935 0.01610629 0.0101204 ]...
#
# 🔹 Chunk 184:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Always foll...
# Embedding: [ 0.03941456 -0.00826544  0.03377967  0.01011353  0.01849943]...
#
# 🔹 Chunk 185:
# Text: In ancient times, transportation was limited to walking and animal domestication. Market voice art b...
# Embedding: [ 0.03489449  0.0321203   0.02313478 -0.01113732  0.00372687]...
#
# 🔹 Chunk 186:
# Text: In ancient times, transportation was limited to walking and animal domestication. Capital product op...
# Embedding: [ 0.02595499  0.04343992  0.04118977 -0.02162056  0.00280116]...
#
# 🔹 Chunk 187:
# Text: In ancient times, transportation was limited to walking and animal domestication. Up charge else tha...
# Embedding: [ 0.00552532  0.02421744  0.00670002  0.00434224 -0.00178567]...
#
# 🔹 Chunk 188:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Try indeed ...
# Embedding: [ 0.02615775  0.02073991  0.03360014  0.00536272 -0.00852831]...
#
# 🔹 Chunk 189:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Design whet...
# Embedding: [-0.01564878 -0.02481084  0.02837843 -0.0218144   0.0110542 ]...
#
# 🔹 Chunk 190:
# Text: In ancient times, transportation was limited to walking and animal domestication. Beat lay plan face...
# Embedding: [ 0.0306678   0.00986767  0.02530866 -0.00401896  0.01242309]...
#
# 🔹 Chunk 191:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Along could carry espe...
# Embedding: [-0.00185704  0.04067458 -0.02954891 -0.01417173 -0.02185405]...
#
# 🔹 Chunk 192:
# Text: The 20th century saw the rise of automobiles and airplanes. War word if light alone represent develo...
# Embedding: [ 0.0221498   0.02394677  0.0348579   0.01862453 -0.02315615]...
#
# 🔹 Chunk 193:
# Text: In ancient times, transportation was limited to walking and animal domestication. Four into lay game...
# Embedding: [ 0.02978138  0.02132136  0.04728809 -0.00152715 -0.02731396]...
#
# 🔹 Chunk 194:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Tax force orde...
# Embedding: [-0.03121676 -0.00185463  0.03345324 -0.00757323  0.00107144]...
#
# 🔹 Chunk 195:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Throw step ...
# Embedding: [ 0.00468764 -0.00575677  0.02040019 -0.0143538   0.00845098]...
#
# 🔹 Chunk 196:
# Text: High-speed trains and subways reshaped urban transportation. Effort station by. Foot face pay custom...
# Embedding: [-0.00396183 -0.03078254 -0.01475924  0.01743817 -0.01485418]...
#
# 🔹 Chunk 197:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Beyond impor...
# Embedding: [0.01682965 0.02182928 0.00412926 0.00704349 0.02493729]...
#
# 🔹 Chunk 198:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Send state former. Kit...
# Embedding: [-0.02453241  0.01531393  0.00856734 -0.00763474 -0.0125908 ]...
#
# 🔹 Chunk 199:
# Text: High-speed trains and subways reshaped urban transportation. Parent skin past if race town town. Tur...
# Embedding: [ 0.00839774  0.01213164 -0.00973127  0.0260307  -0.00439703]...
#
# 🔹 Chunk 200:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Recognize she father d...
# Embedding: [ 0.01118999  0.00631066 -0.01644322  0.00915668  0.02423453]...
#
# 🔹 Chunk 201:
# Text: High-speed trains and subways reshaped urban transportation. Catch huge research item. Stage another...
# Embedding: [ 0.02237321  0.00541399  0.04242691  0.01382293 -0.00791846]...
#
# 🔹 Chunk 202:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Teacher the pa...
# Embedding: [-0.03438562  0.01018605  0.03438289 -0.03670686  0.02280067]...
#
# 🔹 Chunk 203:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Position water Democra...
# Embedding: [ 0.00667016  0.01507761  0.0011868  -0.00928756  0.00434236]...
#
# 🔹 Chunk 204:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Product behind...
# Embedding: [-0.00612654 -0.01447864  0.02492496 -0.00877808  0.02446544]...
#
# 🔹 Chunk 205:
# Text: The invention of the wheel revolutionized human movement. Hospital lead will with. Show church such ...
# Embedding: [ 0.0207946   0.00146275  0.00187198  0.02060051 -0.02104557]...
#
# 🔹 Chunk 206:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Bar avoid p...
# Embedding: [-3.44898071e-05 -9.33795888e-03  1.12373941e-02  1.29507920e-02
#   1.62982531e-02]...
#
# 🔹 Chunk 207:
# Text: High-speed trains and subways reshaped urban transportation. Bad citizen break save society. Ground ...
# Embedding: [ 0.0115531  -0.00992848  0.01275841  0.02767243  0.02533061]...
#
# 🔹 Chunk 208:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Today best ...
# Embedding: [ 0.01197778 -0.00509804  0.01491727  0.02225345  0.01482434]...
#
# 🔹 Chunk 209:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01131822  0.03661477 -0.00467915  0.00636921  0.00986797]...
#
# 🔹 Chunk 210:
# Text: The 20th century saw the rise of automobiles and airplanes. Throw election line. Environmental save ...
# Embedding: [-0.00188003  0.04289387  0.02130161  0.04096729 -0.03292816]...
#
# 🔹 Chunk 211:
# Text: The 20th century saw the rise of automobiles and airplanes. Class class at former wife wrong. Yeah s...
# Embedding: [ 0.02921468 -0.01237329  0.03211877  0.0105479  -0.00091254]...
#
# 🔹 Chunk 212:
# Text: High-speed trains and subways reshaped urban transportation. Develop fund building hand gun trip one...
# Embedding: [ 0.00178753  0.00347322  0.02526194  0.02982456 -0.01138863]...
#
# 🔹 Chunk 213:
# Text: The invention of the wheel revolutionized human movement. Movie eight leave for Mr forget involve. I...
# Embedding: [0.01132728 0.00577375 0.02703719 0.00469263 0.00237701]...
#
# 🔹 Chunk 214:
# Text: High-speed trains and subways reshaped urban transportation. Form left land rate. Serve since unit s...
# Embedding: [-0.01676962  0.02008957  0.01793127  0.02018526 -0.02160846]...
#
# 🔹 Chunk 215:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Form intere...
# Embedding: [0.0097199  0.00163393 0.00545071 0.00427673 0.00782569]...
#
# 🔹 Chunk 216:
# Text: The invention of the wheel revolutionized human movement. Him window very daughter. Save home sure c...
# Embedding: [0.00474542 0.03251379 0.00490577 0.01196957 0.00992941]...
#
# 🔹 Chunk 217:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Opportunity ...
# Embedding: [ 0.01968897 -0.01459423  0.00354353  0.01355524 -0.0015717 ]...
#
# 🔹 Chunk 218:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. All leg wes...
# Embedding: [ 0.02322838  0.00589096 -0.00855542  0.03961898  0.03432815]...
#
# 🔹 Chunk 219:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. H...
# Embedding: [-0.00436484  0.03759415 -0.00765668  0.01204532 -0.01631005]...
#
# 🔹 Chunk 220:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Dog management free ne...
# Embedding: [ 0.01235418  0.03868798 -0.02429536  0.00022231 -0.02089412]...
#
# 🔹 Chunk 221:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Arrive know contain ec...
# Embedding: [-0.01889595  0.0322505  -0.00648926  0.01392424 -0.0355271 ]...
#
# 🔹 Chunk 222:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Provide vote h...
# Embedding: [-0.03317958  0.01492702  0.02041768 -0.0416453  -0.00399772]...
#
# 🔹 Chunk 223:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.00325199  0.05576436 -0.01141945  0.00720308  0.00402621]...
#
# 🔹 Chunk 224:
# Text: The invention of the wheel revolutionized human movement. Night find listen deal. Food range Republi...
# Embedding: [ 0.00942225  0.02292216  0.00349822  0.01951321 -0.00502015]...
#
# 🔹 Chunk 225:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. F...
# Embedding: [0.01032818 0.0506506  0.03123297 0.01591848 0.00845829]...
#
# 🔹 Chunk 226:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Short projec...
# Embedding: [ 0.03796958  0.00067653  0.02747414  0.00121753 -0.01616624]...
#
# 🔹 Chunk 227:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Close weight...
# Embedding: [-0.01609901  0.00758211  0.0188267   0.03929276  0.01231862]...
#
# 🔹 Chunk 228:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [ 0.01057847  0.03935194 -0.02890453  0.02241538 -0.00358123]...
#
# 🔹 Chunk 229:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. On shoulder be...
# Embedding: [-0.03728641  0.00271934  0.03204712 -0.02146282 -0.00607405]...
#
# 🔹 Chunk 230:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. L...
# Embedding: [ 0.01148908  0.03956662 -0.00106968  0.01324319  0.01757458]...
#
# 🔹 Chunk 231:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. A...
# Embedding: [0.01315059 0.02782086 0.02421151 0.02164874 0.02483227]...
#
# 🔹 Chunk 232:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. N...
# Embedding: [ 0.02564329  0.08343824 -0.03440183  0.01483743 -0.02933528]...
#
# 🔹 Chunk 233:
# Text: In ancient times, transportation was limited to walking and animal domestication. Former bag news es...
# Embedding: [0.03005597 0.02799017 0.02080323 0.01256319 0.01523877]...
#
# 🔹 Chunk 234:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. B...
# Embedding: [ 0.01540706  0.03894257 -0.00011101  0.01082307  0.00431975]...
#
# 🔹 Chunk 235:
# Text: The invention of the wheel revolutionized human movement. Material happy return everything bill clea...
# Embedding: [-0.0143208   0.00445718  0.01007227  0.00519621 -0.00426705]...
#
# 🔹 Chunk 236:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Reflect shoulder every...
# Embedding: [ 0.01371375  0.0118924  -0.00919121  0.02973779  0.02299085]...
#
# 🔹 Chunk 237:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Same way pr...
# Embedding: [ 0.03867431 -0.0290103   0.00277949  0.00231838  0.03053296]...
#
# 🔹 Chunk 238:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Seek painting ...
# Embedding: [-0.0090278  -0.02267089  0.0481799  -0.04143931  0.0101601 ]...
#
# 🔹 Chunk 239:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.02080004  0.04458342 -0.01252745  0.00643586  0.0258393 ]...
#
# 🔹 Chunk 240:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Lose health worker rea...
# Embedding: [ 0.02826871  0.01549728 -0.0230818   0.0238218  -0.0034982 ]...
#
# 🔹 Chunk 241:
# Text: High-speed trains and subways reshaped urban transportation. Contain suddenly between why result ima...
# ...
# Embedding: [ 0.02598987 -0.00365457  0.01227095  0.02317409 -0.00416514]...
#
# 🔹 Chunk 1802:
# Text: In ancient times, transportation was limited to walking and animal domestication. Skill source five ...
# Embedding: [0.04010358 0.05303613 0.02007494 0.02081707 0.00306988]...
#
# 🔹 Chunk 1803:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. O...
# Embedding: [-0.00036567  0.05447702 -0.00328652  0.02552182  0.0066732 ]...
#
# 🔹 Chunk 1804:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Yard majori...
# Embedding: [0.02631899 0.00597325 0.01404709 0.02499273 0.03472865]...
#
# 🔹 Chunk 1805:
# Text: High-speed trains and subways reshaped urban transportation. Never increase perform hundred side rel...
# Embedding: [-0.00514691  0.00268135 -0.00798086  0.02471532  0.00143749]...
#
# 🔹 Chunk 1806:
# Text: The invention of the wheel revolutionized human movement. Phone responsibility about field. Small co...
# Embedding: [ 0.01030044 -0.00944962 -0.01103858  0.0035943   0.00717544]...
#
# 🔹 Chunk 1807:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Approach college claim...
# Embedding: [-0.00737698  0.04633828  0.00920779  0.0107638   0.01776219]...
#
# 🔹 Chunk 1808:
# Text: High-speed trains and subways reshaped urban transportation. Should first usually worry company. If ...
# Embedding: [-0.01842211 -0.00961264  0.02216968  0.02371086 -0.01334378]...
#
# 🔹 Chunk 1809:
# Text: The 20th century saw the rise of automobiles and airplanes. Government citizen away media set tend. ...
# Embedding: [-0.00472516  0.03264594  0.0378565   0.02236406  0.01494143]...
#
# 🔹 Chunk 1810:
# Text: The invention of the wheel revolutionized human movement. Would prove college go amount. Probably sa...
# Embedding: [ 0.01283438 -0.02755246  0.03781188  0.03693219  0.00424722]...
#
# 🔹 Chunk 1811:
# Text: In ancient times, transportation was limited to walking and animal domestication. Result hospital wi...
# Embedding: [ 0.03725531  0.02194258  0.01748338  0.02928744 -0.03558775]...
#
# 🔹 Chunk 1812:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Picture call organizat...
# Embedding: [ 0.00406536  0.02676501  0.00981955  0.00714139 -0.00958036]...
#
# 🔹 Chunk 1813:
# Text: The invention of the wheel revolutionized human movement. Billion goal participant prevent year rece...
# Embedding: [ 0.00068257  0.02758101 -0.01993703  0.02563658 -0.0051657 ]...
#
# 🔹 Chunk 1814:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. S...
# Embedding: [ 0.01024414  0.06057407  0.02970827  0.01420817 -0.0006238 ]...
#
# 🔹 Chunk 1815:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Environmenta...
# Embedding: [0.00599326 0.03084777 0.01592846 0.00351549 0.01885573]...
#
# 🔹 Chunk 1816:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Property green miss on...
# Embedding: [-0.00028927  0.02308223 -0.01746688  0.0227414  -0.00400038]...
#
# 🔹 Chunk 1817:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Respond stay I poor be...
# Embedding: [-0.0060276   0.01380112 -0.01324557  0.00834839 -0.00128733]...
#
# 🔹 Chunk 1818:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. P...
# Embedding: [ 0.00811961  0.03352887  0.02701952  0.00824021 -0.02644978]...
#
# 🔹 Chunk 1819:
# Text: High-speed trains and subways reshaped urban transportation. Theory employee book action lawyer she ...
# Embedding: [ 0.00200116 -0.00846708  0.01309978  0.01026817 -0.02036246]...
#
# 🔹 Chunk 1820:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Together little collec...
# Embedding: [ 0.01203775  0.01812966 -0.01666613  0.01920268 -0.01724535]...
#
# 🔹 Chunk 1821:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Mother break s...
# Embedding: [-0.00951078  0.01329778  0.04156922 -0.01522564 -0.01338077]...
#
# 🔹 Chunk 1822:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Tax determine ...
# Embedding: [-0.02153331  0.00441434  0.01583429  0.00365962  0.00467127]...
#
# 🔹 Chunk 1823:
# Text: The invention of the wheel revolutionized human movement. Possible movement full read give because c...
# Embedding: [ 0.01960735  0.00296849  0.0044962   0.01899218 -0.00147148]...
#
# 🔹 Chunk 1824:
# Text: The 20th century saw the rise of automobiles and airplanes. Quite theory quite shoulder explain. Edu...
# Embedding: [ 0.02983622  0.02656946  0.04617533  0.00337558 -0.00163047]...
#
# 🔹 Chunk 1825:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Boy affect team teach ...
# Embedding: [ 0.02404475  0.02469585  0.01209836  0.02089115 -0.0154057 ]...
#
# 🔹 Chunk 1826:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Push month abi...
# Embedding: [-0.02817407  0.00789873  0.02151793 -0.0558874  -0.00517088]...
#
# 🔹 Chunk 1827:
# Text: The invention of the wheel revolutionized human movement. Else face whose surface around friend miss...
# Embedding: [ 0.02255735  0.0076279   0.02833792  0.00226597 -0.0038821 ]...
#
# 🔹 Chunk 1828:
# Text: In ancient times, transportation was limited to walking and animal domestication. Since matter hear ...
# Embedding: [ 0.02100437 -0.00197739  0.04368927  0.024505    0.02201889]...
#
# 🔹 Chunk 1829:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. A...
# Embedding: [ 0.00816767  0.04212041  0.02564541  0.02898772 -0.00532745]...
#
# 🔹 Chunk 1830:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Me debate foot...
# Embedding: [-0.02574332  0.01532349  0.01408422 -0.05414388 -0.0137919 ]...
#
# 🔹 Chunk 1831:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Decade spring national...
# Embedding: [0.00339241 0.02762788 0.02460537 0.03136258 0.027265  ]...
#
# 🔹 Chunk 1832:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Adult bill ...
# Embedding: [ 0.02552824 -0.01211064  0.0132396   0.02053889  0.01631374]...
#
# 🔹 Chunk 1833:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Shake hand ...
# Embedding: [ 0.03378115 -0.00445152  0.02127353  0.0336579   0.01449844]...
#
# 🔹 Chunk 1834:
# Text: The 20th century saw the rise of automobiles and airplanes. Responsibility culture worry myself. Hop...
# Embedding: [-0.00137347  0.00013367  0.04556338  0.03694458 -0.0302715 ]...
#
# 🔹 Chunk 1835:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Age young b...
# Embedding: [ 0.01975495 -0.01169867  0.00584159 -0.00065714  0.0340033 ]...
#
# 🔹 Chunk 1836:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Statement le...
# Embedding: [ 0.00192413  0.01498248 -0.01417371  0.01517559  0.03737085]...
#
# 🔹 Chunk 1837:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Management ...
# Embedding: [ 0.0250705  -0.00484781 -0.00771481  0.01367829  0.01097435]...
#
# 🔹 Chunk 1838:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Air late do ...
# Embedding: [ 1.49482423e-02 -1.16480170e-02 -1.71754621e-02  1.95617229e-02
#  -1.33858239e-05]...
#
# 🔹 Chunk 1839:
# Text: In ancient times, transportation was limited to walking and animal domestication. Here church thing ...
# Embedding: [ 0.03840951  0.02791932  0.02307715  0.01627032 -0.00173256]...
#
# 🔹 Chunk 1840:
# Text: In ancient times, transportation was limited to walking and animal domestication. Military family sp...
# Embedding: [ 0.02925016  0.01685839  0.03679409  0.00902824 -0.00680192]...
#
# 🔹 Chunk 1841:
# Text: In ancient times, transportation was limited to walking and animal domestication. Recently whose are...
# Embedding: [ 0.02547967  0.02933832  0.04458301  0.00294503 -0.02112413]...
#
# 🔹 Chunk 1842:
# Text: The invention of the wheel revolutionized human movement. Civil entire happen relationship. Describe...
# Embedding: [0.00751877 0.00750012 0.0435655  0.00827758 0.00796756]...
#
# 🔹 Chunk 1843:
# Text: High-speed trains and subways reshaped urban transportation. Into require direction event tonight. V...
# Embedding: [ 0.02431776 -0.00701947 -0.0095875   0.01389248 -0.00782967]...
#
# 🔹 Chunk 1844:
# Text: High-speed trains and subways reshaped urban transportation. Time environment tough think art green ...
# Embedding: [-0.02986571 -0.01938058  0.02589981  0.02089968  0.00246786]...
#
# 🔹 Chunk 1845:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Want recent re...
# Embedding: [ 0.00878208 -0.00057883 -0.011355   -0.02510864 -0.00368737]...
#
# 🔹 Chunk 1846:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Soon four well once. S...
# Embedding: [ 0.00925463  0.01210927 -0.00613829  0.00089853  0.00234713]...
#
# 🔹 Chunk 1847:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. But drive you most. Do...
# Embedding: [0.00854206 0.00823844 0.01223468 0.01666017 0.00670371]...
#
# 🔹 Chunk 1848:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Another rich t...
# Embedding: [-0.02903144  0.00608831  0.02746204 -0.02597898 -0.00046068]...
#
# 🔹 Chunk 1849:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Treatment lo...
# Embedding: [ 0.00860447 -0.01098527 -0.01518534  0.04101809  0.00967999]...
#
# 🔹 Chunk 1850:
# Text: High-speed trains and subways reshaped urban transportation. Its stop spend career. Reach then life ...
# Embedding: [ 0.01784617 -0.00284131  0.02348716  0.01698436 -0.01368511]...
#
# 🔹 Chunk 1851:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Return weigh...
# Embedding: [ 0.00674056 -0.02104054 -0.00204643  0.03397538  0.00327215]...
#
# 🔹 Chunk 1852:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Section skill wrong fo...
# Embedding: [0.03662    0.02493178 0.01954569 0.00514672 0.02709008]...
#
# 🔹 Chunk 1853:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Wonder camera involve ...
# Embedding: [ 0.02149553 -0.00832878  0.00259958  0.01313859  0.02499649]...
#
# 🔹 Chunk 1854:
# Text: In ancient times, transportation was limited to walking and animal domestication. Lose space paper. ...
# Embedding: [ 0.03855628 -0.00506022  0.05023286  0.00795206 -0.02843344]...
#
# 🔹 Chunk 1855:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Across true party here...
# Embedding: [ 0.01375211  0.01651616 -0.00888504  0.01591276  0.0272405 ]...
#
# 🔹 Chunk 1856:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Better focus...
# Embedding: [ 0.00455242 -0.01717699 -0.00543741  0.02437945  0.00088794]...
#
# 🔹 Chunk 1857:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Admit media ...
# Embedding: [ 0.01301945 -0.01624388  0.0136562   0.03027344  0.03263794]...
#
# 🔹 Chunk 1858:
# Text: The fusion of AI and transportation is giving rise to smart mobility systems. Its already less drop....
# Embedding: [0.02114423 0.04362551 0.02730916 0.01660328 0.01500399]...
#
# 🔹 Chunk 1859:
# Text: High-speed trains and subways reshaped urban transportation. Attack section on reason possible natur...
# Embedding: [ 0.02237337 -0.00847144  0.03923545  0.03168493 -0.0049527 ]...
#
# 🔹 Chunk 1860:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. G...
# Embedding: [ 0.00648408  0.05532336 -0.01189466  0.00899382 -0.00409751]...
#
# 🔹 Chunk 1861:
# Text: The invention of the wheel revolutionized human movement. Crime blood mouth test through role face. ...
# Embedding: [ 0.00532285 -0.01397413  0.02066831  0.00119058  0.01346139]...
#
# 🔹 Chunk 1862:
# Text: In ancient times, transportation was limited to walking and animal domestication. Success return alo...
# Embedding: [ 0.02825404  0.02526499  0.01600973 -0.01756641  0.0055168 ]...
#
# 🔹 Chunk 1863:
# Text: In ancient times, transportation was limited to walking and animal domestication. Among begin tend s...
# Embedding: [ 0.00913653  0.00220882  0.02393499 -0.00805143 -0.00224975]...
#
# 🔹 Chunk 1864:
# Text: During the Industrial Revolution, steam engines transformed both land and sea travel. Style hard gla...
# Embedding: [-0.00402159 -0.01278689  0.02785769 -0.0308263  -0.00744853]...
#
# 🔹 Chunk 1865:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. R...
# Embedding: [ 0.01072045  0.06324036  0.02171366  0.02027046 -0.01227068]...
#
# 🔹 Chunk 1866:
# Text: The 20th century saw the rise of automobiles and airplanes. Feeling activity own few service structu...
# Embedding: [ 0.00571219  0.02982277  0.0224927   0.04144077 -0.02853774]...
#
# 🔹 Chunk 1867:
# Text: High-speed trains and subways reshaped urban transportation. World data effort occur. Do top piece l...
# Embedding: [0.02897717 0.00926021 0.03121647 0.03663858 0.00316598]...
#
# 🔹 Chunk 1868:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Crime someth...
# Embedding: [-0.00496141 -0.00995012  0.00078835  0.04615464  0.00663843]...
#
# 🔹 Chunk 1869:
# Text: The 20th century saw the rise of automobiles and airplanes. Program everyone large close far college...
# Embedding: [ 0.0139492   0.0111273   0.03575272 -0.00349774 -0.03490724]...
#
# 🔹 Chunk 1870:
# Text: The 20th century saw the rise of automobiles and airplanes. Firm type cell offer enter yourself even...
# Embedding: [ 0.00031001  0.01138613  0.03121058  0.00048115 -0.0245263 ]...
#
# 🔹 Chunk 1871:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Kid big with...
# Embedding: [0.0103765  0.01209523 0.01364032 0.03260495 0.00969318]...
#
# 🔹 Chunk 1872:
# Text: Governments worldwide are investing in infrastructure to support new transport methods. Gun small th...
# Embedding: [ 0.01824815 -0.01255116 -0.01184268  0.01275441  0.00969352]...
#
# 🔹 Chunk 1873:
# Text: In ancient times, transportation was limited to walking and animal domestication. Million already bi...
# Embedding: [0.03264011 0.04416882 0.01762258 0.02547825 0.0043913 ]...
#
# 🔹 Chunk 1874:
# Text: Sustainable transportation is becoming increasingly important in the fight against climate change. T...
# Embedding: [ 0.00273238  0.01821041 -0.0052631   0.03125836 -0.01114648]...
#
# 🔹 Chunk 1875:
# Text: The invention of the wheel revolutionized human movement. Important mean almost because. Clear famil...
# Embedding: [0.00906724 0.02736569 0.01009212 0.05208743 0.01013868]...
#
# 🔹 Chunk 1876:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Already the...
# Embedding: [ 0.02147646 -0.0105885   0.00532412  0.02095545  0.03482546]...
#
# 🔹 Chunk 1877:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Beautiful year key rel...
# Embedding: [-0.01020183 -0.00535212 -0.00328797  0.01829775 -0.0134814 ]...
#
# 🔹 Chunk 1878:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Education federal afte...
# Embedding: [ 0.00223447  0.01014669  0.00137032 -0.01312007  0.00644355]...
#
# 🔹 Chunk 1879:
# Text: Today, electric vehicles and autonomous cars represent a new era of mobility. Need contain step hers...
# Embedding: [-0.02231126  0.00214165 -0.0185562  -0.00857553  0.00879979]...
#
# 🔹 Chunk 1880:
# Text: Futuristic ideas such as hyperloops, flying cars, and space travel dominate discussions. Number both...
# Embedding: [ 0.04433665 -0.01722114 -0.01294652  0.00744267  0.0242571 ]...

# %%
# Step 10: Process user query for keyword and vector search
query = "transportation innovations"  # Example query; replace with user input

# Keyword search on Chroma DB
try:
    keyword_results = vectorstore.similarity_search(query, k=5)
    print(f"\nKeyword search results for '{query}':")
    for i, result in enumerate(keyword_results):
        print(f"Result {i+1}:")
        print(f"Content: {result.page_content[:100]}...")
        print(f"Metadata: {result.metadata}")
except Exception as e:
    print(f"Error in keyword search: {e}")
    keyword_results = []
# Out:
# Keyword search results for 'transportation innovations':
# Result 1:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}
# Result 2:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}
# Result 3:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}
# Result 4:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}
# Result 5:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}

# %%
# Step 11: Embed the query
try:
    embedded_query = embedding_model.embed_query(query)
    print(f"\nEmbedded query (first 5 dimensions): {embedded_query[:5]}...")
except Exception as e:
    print(f"Error embedding query: {e}")
    embedded_query = [0.0] * 1024  # Fallback: zero vector
# Out:
# Embedded query (first 5 dimensions): [0.009404521, 0.009462016, 0.0059296805, 4.9838603e-05, 0.0012932946]...

# %%
# Step 12: Vector search using embedded query
try:
    vector_results = vectorstore.similarity_search_by_vector(embedded_query, k=2)
    print(f"\nVector search results for '{query}':")
    for i, result in enumerate(vector_results):
        print(f"Result {i+1}:")
        print(f"Content: {result.page_content[:100]}...")
        print(f"Metadata: {result.metadata}")
except Exception as e:
    print(f"Error in vector search: {e}")
    vector_results = []
# Out:
# Vector search results for 'transportation innovations':
# Result 1:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}
# Result 2:
# Content: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
# Metadata: {}

# %%
# Step 13: Combine and deduplicate chunks
combined_chunks = []
chunk_texts = set()  # For deduplication
for result in keyword_results + vector_results:
    chunk_text = result.page_content
    if chunk_text not in chunk_texts:
        combined_chunks.append(chunk_text)
        chunk_texts.add(chunk_text)
print(f"\nCombined unique chunks: {len(combined_chunks)}")
# Out:
# Combined unique chunks: 1

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Step 14.1: Deduplicate chunks
unique_chunks = list(set(combined_chunks))

# Step 14.2: TF-IDF re-ranking based on cosine similarity
vectorizer = TfidfVectorizer().fit([query] + combined_chunks)
query_vec = vectorizer.transform([query])
chunk_vecs = vectorizer.transform(combined_chunks)
similarities = cosine_similarity(query_vec, chunk_vecs).flatten()

# Step 14.3: Print similarity scores for all chunks
print("🔎 Cosine Similarity Scores:")
for i, (chunk, score) in enumerate(zip(unique_chunks, similarities)):
    preview = chunk[:100].replace("\n", " ") + ("..." if len(chunk) > 100 else "")
    print(f"[{i}] Score: {score:.4f} | Chunk: {preview}")


# Step 14.4: Rank chunks by similarity and select top-k (e.g., top 5)
top_k = 5
top_indices = np.argsort(similarities)[::-1][:top_k]
reranked_chunks = [combined_chunks[i] for i in top_indices]

# Step 14.4: Print top-k chunks and their scores
print(f"\n📌 Top-{top_k} Most Relevant Chunks:")
for rank, idx in enumerate(top_indices, start=1):
    score = similarities[idx]
    chunk = unique_chunks[idx]
    preview = chunk[:300].replace("\n", " ") + ("..." if len(chunk) > 300 else "")
    print(f"\n#{rank} | Score: {score:.4f}\n{preview}")

# Step 14.5: Optional prompt compression: truncate each chunk to 300 characters
compressed_chunks = [chunk[:300] for chunk in reranked_chunks]

# Step 14.6: Rebuild final context for LLM
context = "\n\n".join(compressed_chunks)
llm_input = f"Query: {query}\n\nContext:\n{context}\n\nAnswer:"
print("Re-ranked and compressed context prepared for LLM.")
# Out:
# 🔎 Cosine Similarity Scores:
# [0] Score: 0.0000 | Chunk: Governments worldwide are investing in infrastructure to support new transport methods. Face ready i...
#
# 📌 Top-5 Most Relevant Chunks:
#
# #1 | Score: 0.0000
# Governments worldwide are investing in infrastructure to support new transport methods. Face ready issue that party identify. Subject management interesting idea if finally cold. Business performance city test direction call.  The invention of the wheel revolutionized human movement. Small finish te...
# Re-ranked and compressed context prepared for LLM.

# %%
#Step 14: Prepare context for LLM
context = "\n\n".join(combined_chunks)
llm_input = f"Query: {query}\n\nContext:\n{context}\n\nAnswer the query based on the provided context."

# %%
# Step 15: Call LLM (llama3.2-vision:11b) via Ollama API
llm_url = "http://localhost:11434/v1/chat/completions"
llm_headers = {"Content-Type": "application/json"}
llm_data = {
    "model": "llama3.2-vision:11b",
    "messages": [
        {"role": "system", "content": "You are a helpful assistant. Answer the query using the provided context."},
        {"role": "user", "content": llm_input}
    ],
    "max_tokens": 500
}
try:
    response = requests.post(llm_url, headers=llm_headers, json=llm_data)
    response.raise_for_status()
    llm_response = response.json()["choices"][0]["message"]["content"]
    print(f"\nLLM Response for query '{query}':")
    print(llm_response)
except requests.RequestException as e:
    print(f"Error calling LLM: {e}")
    llm_response = "Failed to generate response."
# Out:
# Error calling LLM: 500 Server Error: Internal Server Error for url: http://localhost:11434/v1/chat/completions
